# %%
import spacy
import pandas as pd
import en_core_web_md
import ast

# %%
# load medium English model in case we need to work with vectors
nlp = en_core_web_md.load()

# %%
df = pd.read_csv('Neighborhood_Separated_Articles/2014.csv')

# %%
black_neighborhoods = ['dorchester', 'roxbury', 'mattapan', 'hyde_park']
white_neighborhoods = ['fenway', 'beacon_hill', 'downtown', 'south_boston', 'east_boston', 'back_bay', 'jamaica_plain',
                      'south_end', 'charlestown', 'brighton', 'allston', 'west_end', 'roslindale', 'north_end',
                      'mission_hill', 'harbor_islands', 'longwood_medical_area', 'west_roxbury']
df = df.fillna("('no article', 'no_id')")
df['dorchester'] = df['dorchester'].apply(ast.literal_eval)
df['roxbury'] = df['roxbury'].apply(ast.literal_eval)
df['mattapan'] = df['mattapan'].apply(ast.literal_eval)
df['hyde_park'] = df['hyde_park'].apply(ast.literal_eval)
df['fenway'] = df['fenway'].apply(ast.literal_eval)
df['beacon_hill'] = df['beacon_hill'].apply(ast.literal_eval)
df['downtown'] = df['downtown'].apply(ast.literal_eval)
df['south_boston'] = df['south_boston'].apply(ast.literal_eval)
df['east_boston'] = df['east_boston'].apply(ast.literal_eval)
df['back_bay'] = df['back_bay'].apply(ast.literal_eval)
df['jamaica_plain'] = df['jamaica_plain'].apply(ast.literal_eval)
df['south_end'] = df['south_end'].apply(ast.literal_eval)
df['charlestown'] = df['charlestown'].apply(ast.literal_eval)
df['brighton'] = df['brighton'].apply(ast.literal_eval)
df['allston'] = df['allston'].apply(ast.literal_eval)
df['west_end'] = df['west_end'].apply(ast.literal_eval)
df['roslindale'] = df['roslindale'].apply(ast.literal_eval)
df['north_end'] = df['north_end'].apply(ast.literal_eval)
df['mission_hill'] = df['mission_hill'].apply(ast.literal_eval)
df['harbor_islands'] = df['harbor_islands'].apply(ast.literal_eval)
df['longwood_medical_area'] = df['longwood_medical_area'].apply(ast.literal_eval)
df['west_roxbury'] = df['west_roxbury'].apply(ast.literal_eval)

# %%
spec_chars = ["!",'"',"#","%","&","'","(",")", "*","+",",",
                  "-",".","/",":",";","<", "=",">","?","@","[",
                  "\\","]","^","_", "`","{","|","}","~","–", 
                  "\xc2", "\xa0", "\x80", "\x9c", "\x99", "\x94", 
                  "\xad", "\xe2", "\x9d", "\n"]

df = df.drop(['Unnamed: 0'], axis=1)

#for char in spec_chars:
#    df['text'] = df['text'].str.strip()
#    df['text'] = df['text'].str.replace(char, ' ')
       
# access each column separately
for i in range(len(df.index)):
    for col in df.columns:
        for char in spec_chars:
            try:
                df.loc[i, col][0] = df.loc[i, col][0].str.strip()
                df.loc[i, col][0] = df.loc[i, col][0].str.replace(char, ' ')
            except:
                pass

# %%
df.shape
# Out:
# (500, 22)

# %%
articles = {'hyde_park': [], 'beacon_hill': [], 'south_boston': [], 'jamaica_plain': [], 'east_boston': [],
                'south_end': [], 'back_bay': [], 'north_end': [], 'west_roxbury': [], 'mission_hill': [],
                'harbor_islands': [], 'west_end': [], 'longwood_medical_area': [],
                'dorchester': [], 'roxbury': [], 'downtown': [], 'fenway': [], 'mattapan': [], 'brighton': [],
                'charlestown': [], 'roslindale': [], 'allston': []}
for sub_neighborhood in articles.keys():
    for i in range(df.shape[0]):
        if type(df.loc[i, sub_neighborhood]) == tuple:
            articles[sub_neighborhood].append((nlp(df.loc[i, sub_neighborhood][0]), df.loc[i, sub_neighborhood][1]))
    print(sub_neighborhood + ' DONE')
# Out:
# hyde_park DONE
# beacon_hill DONE
# south_boston DONE
# jamaica_plain DONE
# east_boston DONE
# south_end DONE
# back_bay DONE
# north_end DONE
# west_roxbury DONE
# mission_hill DONE
# harbor_islands DONE
# west_end DONE
# longwood_medical_area DONE
# dorchester DONE
# roxbury DONE
# downtown DONE
# fenway DONE
# mattapan DONE
# brighton DONE
# charlestown DONE
# roslindale DONE
# allston DONE

# %%
articles['dorchester'][0][1]
# Out:
# '2014_5'

# %%
people = {'hyde_park': [], 'beacon_hill': [], 'south_boston': [], 'jamaica_plain': [], 'east_boston': [],
                'south_end': [], 'back_bay': [], 'north_end': [], 'west_roxbury': [], 'mission_hill': [],
                'harbor_islands': [], 'west_end': [], 'longwood_medical_area': [],
                'dorchester': [], 'roxbury': [], 'downtown': [], 'fenway': [], 'mattapan': [], 'brighton': [],
                'charlestown': [], 'roslindale': [], 'allston': []}

for sub_neighborhood in articles.keys():
    for (doc, article_id) in articles[sub_neighborhood]:
        for ent in doc.ents:
            if ent.label_ == 'PERSON':
                name = ent[0:2]
                # sentence = ent.sent
                people[sub_neighborhood].append((name, article_id))

# %%
for sub_neighborhood in people.keys():
    list1 = people[sub_neighborhood]
    # convert the list to the set
    list_set = set(list1)
    # convert the set to the list
    unique_list = (list(list_set))
    people[sub_neighborhood] = unique_list

# %%
representation_proportions = {'hyde_park': [], 'beacon_hill': [], 'south_boston': [], 'jamaica_plain': [], 'east_boston': [],
                'south_end': [], 'back_bay': [], 'north_end': [], 'west_roxbury': [], 'mission_hill': [],
                'harbor_islands': [], 'west_end': [], 'longwood_medical_area': [],
                'dorchester': [], 'roxbury': [], 'downtown': [], 'fenway': [], 'mattapan': [], 'brighton': [],
                'charlestown': [], 'roslindale': [], 'allston': []}
for sub_neighborhood in people.keys():
    for i in range(len(people[sub_neighborhood])):
        if people[sub_neighborhood][i][0].text.strip() != '':
            temp = people[sub_neighborhood][i][0].text.split()
            if len(temp) > 1:
                people[sub_neighborhood][i] = (temp[0], people[sub_neighborhood][i][1])
            else:
                people[sub_neighborhood][i] = (temp[0], people[sub_neighborhood][i][1])

# %%
people['dorchester'][0]
# Out:
# ('Dan', '2014_216')

# %%
from ethnicolr import pred_wiki_ln

# %%
# temp = pd.DataFrame(people['fenway'], columns=['last_name', 'article_id'])
# temp = temp.drop(['article_id'], axis=1)
# temp['subneighborhood'] = 'fenway'
# temp.head()

# %%
final_df = pd.DataFrame(columns=['last_name', 'subneighborhood'])
subs = white_neighborhoods + black_neighborhoods
subs.remove('longwood_medical_area')
for col in subs:
    temp = pd.DataFrame(people[col], columns=['last_name', 'article_id'])
    temp = temp.drop(['article_id'], axis=1)
    temp['subneighborhood'] = col
    preds = pred_wiki_ln(temp, 'last_name')
    final_df = pd.concat([final_df, preds], axis=0)
    print(col + ' DONE')
# Out:
# fenway DONE
# beacon_hill DONE
# downtown DONE
# south_boston DONE
# east_boston DONE
# back_bay DONE
# jamaica_plain DONE
# south_end DONE
# charlestown DONE
# brighton DONE
# allston DONE
# west_end DONE
# roslindale DONE
# north_end DONE
# mission_hill DONE
# harbor_islands DONE
# west_roxbury DONE
# dorchester DONE
# roxbury DONE
# mattapan DONE
# hyde_park DONE

# %%
hen = final_df['race'].value_counts()
pd.DataFrame(hen)
# Out:
#                                         race
# GreaterEuropean,British                20493
# GreaterEuropean,WestEuropean,French     2068
# GreaterEuropean,WestEuropean,Italian    2054
# GreaterEuropean,WestEuropean,Hispanic   1487
# GreaterEuropean,Jewish                  1300
# Asian,IndianSubContinent                1134
# Asian,GreaterEastAsian,EastAsian         947
# GreaterAfrican,Muslim                    663
# GreaterEuropean,WestEuropean,Nordic      368
# GreaterEuropean,EastEuropean             357
# GreaterAfrican,Africans                  253
# Asian,GreaterEastAsian,Japanese          241
# GreaterEuropean,WestEuropean,Germanic    182

# %%
groups = final_df.groupby(final_df.subneighborhood)
race_df = pd.DataFrame(columns=subs)
races = final_df.race.unique()
for col in subs:
    group = groups.get_group(col)
    race_df[col] = group.race.value_counts()

# %%
race_df = race_df.fillna(0.0)
race_df
# Out:
#                                        fenway  beacon_hill  downtown  \
# GreaterEuropean,British                   232          620       655
# GreaterEuropean,WestEuropean,Italian       96           26       178
# GreaterEuropean,WestEuropean,Hispanic      74           15        82
# Asian,IndianSubContinent                   59           65        30
# Asian,GreaterEastAsian,EastAsian           54           20        52
# GreaterEuropean,Jewish                     38           65        63
# GreaterEuropean,WestEuropean,French        20           34        67
# GreaterEuropean,EastEuropean               14            3        25
# GreaterAfrican,Muslim                       9           16        27
# GreaterEuropean,WestEuropean,Nordic         5            5        13
# GreaterAfrican,Africans                     2            8        13
# Asian,GreaterEastAsian,Japanese             1            6        16
# GreaterEuropean,WestEuropean,Germanic       1            2        14
#
#                                        south_boston  east_boston  back_bay  \
# GreaterEuropean,British                        1782          365       973
# GreaterEuropean,WestEuropean,Italian            116           63        69
# GreaterEuropean,WestEuropean,Hispanic            81          225        18
# Asian,IndianSubContinent                         65            6        66
# Asian,GreaterEastAsian,EastAsian                101           16        15
# GreaterEuropean,Jewish                          138           19        27
# GreaterEuropean,WestEuropean,French             150           34        74
# GreaterEuropean,EastEuropean                     43            6         7
# GreaterAfrican,Muslim                            39           19        44
# GreaterEuropean,WestEuropean,Nordic              21            4        68
# GreaterAfrican,Africans                          16            5         6
# Asian,GreaterEastAsian,Japanese                   8            5         4
# GreaterEuropean,WestEuropean,Germanic            40            3         7
#
#                                        jamaica_plain  south_end  charlestown  \
# GreaterEuropean,British                          672        636        165.0
# GreaterEuropean,WestEuropean,Italian              57         53          5.0
# GreaterEuropean,WestEuropean,Hispanic             66         28         12.0
# Asian,IndianSubContinent                          52         20          5.0
# Asian,GreaterEastAsian,EastAsian                  21         18          3.0
# GreaterEuropean,Jewish                            37         28          3.0
# GreaterEuropean,WestEuropean,French               77        129          8.0
# GreaterEuropean,EastEuropean                      12          7          4.0
# GreaterAfrican,Muslim                             24         19         11.0
# GreaterEuropean,WestEuropean,Nordic                9         15          0.0
# GreaterAfrican,Africans                            9          8          4.0
# Asian,GreaterEastAsian,Japanese                    9          1          1.0
# GreaterEuropean,WestEuropean,Germanic              9          8          0.0
#
#                                        brighton  ...  west_end  roslindale  \
# GreaterEuropean,British                   217.0  ...      66.0         365
# GreaterEuropean,WestEuropean,Italian       13.0  ...       8.0          71
# GreaterEuropean,WestEuropean,Hispanic      18.0  ...       6.0          49
# Asian,IndianSubContinent                    7.0  ...       4.0          20
# Asian,GreaterEastAsian,EastAsian            9.0  ...       4.0           6
# GreaterEuropean,Jewish                      7.0  ...       2.0          33
# GreaterEuropean,WestEuropean,French         5.0  ...       9.0          29
# GreaterEuropean,EastEuropean                2.0  ...       0.0           8
# GreaterAfrican,Muslim                       2.0  ...       3.0          11
# GreaterEuropean,WestEuropean,Nordic         0.0  ...       3.0           2
# GreaterAfrican,Africans                     2.0  ...       9.0           8
# Asian,GreaterEastAsian,Japanese             0.0  ...       1.0           2
# GreaterEuropean,WestEuropean,Germanic       6.0  ...       1.0           2
#
#                                        north_end  mission_hill  \
# GreaterEuropean,British                     93.0         357.0
# GreaterEuropean,WestEuropean,Italian        26.0          13.0
# GreaterEuropean,WestEuropean,Hispanic        4.0           7.0
# Asian,IndianSubContinent                     1.0          30.0
# Asian,GreaterEastAsian,EastAsian            13.0           2.0
# GreaterEuropean,Jewish                      17.0          12.0
# GreaterEuropean,WestEuropean,French         10.0          16.0
# GreaterEuropean,EastEuropean                 1.0           5.0
# GreaterAfrican,Muslim                        5.0          52.0
# GreaterEuropean,WestEuropean,Nordic          6.0           1.0
# GreaterAfrican,Africans                      3.0           0.0
# Asian,GreaterEastAsian,Japanese              0.0          17.0
# GreaterEuropean,WestEuropean,Germanic        1.0           1.0
#
#                                        harbor_islands  west_roxbury  \
# GreaterEuropean,British                           4.0           706
# GreaterEuropean,WestEuropean,Italian              0.0            59
# GreaterEuropean,WestEuropean,Hispanic             7.0            20
# Asian,IndianSubContinent                          0.0            40
# Asian,GreaterEastAsian,EastAsian                  0.0            19
# GreaterEuropean,Jewish                            0.0            43
# GreaterEuropean,WestEuropean,French               0.0            49
# GreaterEuropean,EastEuropean                      0.0            15
# GreaterAfrican,Muslim                             0.0            17
# GreaterEuropean,WestEuropean,Nordic               0.0            10
# GreaterAfrican,Africans                           0.0             6
# Asian,GreaterEastAsian,Japanese                   0.0             3
# GreaterEuropean,WestEuropean,Germanic             0.0             2
#
#                                        dorchester  roxbury  mattapan  \
# GreaterEuropean,British                      7599     2705       562
# GreaterEuropean,WestEuropean,Italian          568      185        52
# GreaterEuropean,WestEuropean,Hispanic         542      116        26
# Asian,IndianSubContinent                      328      169        29
# Asian,GreaterEastAsian,EastAsian              320      102        23
# GreaterEuropean,Jewish                        370      220        43
# GreaterEuropean,WestEuropean,French           925      204        62
# GreaterEuropean,EastEuropean                  147       41         3
# GreaterAfrican,Muslim                         139      187         4
# GreaterEuropean,WestEuropean,Nordic           147       34        11
# GreaterAfrican,Africans                        92       45         3
# Asian,GreaterEastAsian,Japanese                85       46         7
# GreaterEuropean,WestEuropean,Germanic          58       14         1
#
#                                        hyde_park
# GreaterEuropean,British                     1513
# GreaterEuropean,WestEuropean,Italian         381
# GreaterEuropean,WestEuropean,Hispanic         77
# Asian,IndianSubContinent                     115
# Asian,GreaterEastAsian,EastAsian             144
# GreaterEuropean,Jewish                       118
# GreaterEuropean,WestEuropean,French          149
# GreaterEuropean,EastEuropean                  11
# GreaterAfrican,Muslim                         28
# GreaterEuropean,WestEuropean,Nordic           14
# GreaterAfrican,Africans                       11
# Asian,GreaterEastAsian,Japanese               29
# GreaterEuropean,WestEuropean,Germanic         11
#
# [13 rows x 21 columns]

# %%
for i in range(len(subs)):
    tot = race_df[subs[i]].sum()
    for j in race_df.index:
        race_df.loc[j, [subs[i]]] = (race_df.loc[j, [subs[i]]] / tot) * 100

# %%
race_df
# Out:
#                                           fenway  beacon_hill   downtown  \
# GreaterEuropean,British                38.347107    70.056497  53.036437
# GreaterEuropean,WestEuropean,Italian   15.867769     2.937853  14.412955
# GreaterEuropean,WestEuropean,Hispanic  12.231405     1.694915   6.639676
# Asian,IndianSubContinent                9.752066     7.344633   2.429150
# Asian,GreaterEastAsian,EastAsian        8.925620     2.259887   4.210526
# GreaterEuropean,Jewish                  6.280992     7.344633   5.101215
# GreaterEuropean,WestEuropean,French     3.305785     3.841808   5.425101
# GreaterEuropean,EastEuropean            2.314050     0.338983   2.024291
# GreaterAfrican,Muslim                   1.487603     1.807910   2.186235
# GreaterEuropean,WestEuropean,Nordic     0.826446     0.564972   1.052632
# GreaterAfrican,Africans                 0.330579     0.903955   1.052632
# Asian,GreaterEastAsian,Japanese         0.165289     0.677966   1.295547
# GreaterEuropean,WestEuropean,Germanic   0.165289     0.225989   1.133603
#
#                                        south_boston  east_boston   back_bay  \
# GreaterEuropean,British                   68.538462    47.402597  70.609579
# GreaterEuropean,WestEuropean,Italian       4.461538     8.181818   5.007257
# GreaterEuropean,WestEuropean,Hispanic      3.115385    29.220779   1.306241
# Asian,IndianSubContinent                   2.500000     0.779221   4.789550
# Asian,GreaterEastAsian,EastAsian           3.884615     2.077922   1.088534
# GreaterEuropean,Jewish                     5.307692     2.467532   1.959361
# GreaterEuropean,WestEuropean,French        5.769231     4.415584   5.370102
# GreaterEuropean,EastEuropean               1.653846     0.779221   0.507983
# GreaterAfrican,Muslim                      1.500000     2.467532   3.193033
# GreaterEuropean,WestEuropean,Nordic        0.807692     0.519481   4.934688
# GreaterAfrican,Africans                    0.615385     0.649351   0.435414
# Asian,GreaterEastAsian,Japanese            0.307692     0.649351   0.290276
# GreaterEuropean,WestEuropean,Germanic      1.538462     0.389610   0.507983
#
#                                        jamaica_plain  south_end  charlestown  \
# GreaterEuropean,British                    63.757116  65.567010    74.660633
# GreaterEuropean,WestEuropean,Italian        5.407970   5.463918     2.262443
# GreaterEuropean,WestEuropean,Hispanic       6.261860   2.886598     5.429864
# Asian,IndianSubContinent                    4.933586   2.061856     2.262443
# Asian,GreaterEastAsian,EastAsian            1.992410   1.855670     1.357466
# GreaterEuropean,Jewish                      3.510436   2.886598     1.357466
# GreaterEuropean,WestEuropean,French         7.305503  13.298969     3.619910
# GreaterEuropean,EastEuropean                1.138520   0.721649     1.809955
# GreaterAfrican,Muslim                       2.277040   1.958763     4.977376
# GreaterEuropean,WestEuropean,Nordic         0.853890   1.546392     0.000000
# GreaterAfrican,Africans                     0.853890   0.824742     1.809955
# Asian,GreaterEastAsian,Japanese             0.853890   0.103093     0.452489
# GreaterEuropean,WestEuropean,Germanic       0.853890   0.824742     0.000000
#
#                                         brighton  ...   west_end  roslindale  \
# GreaterEuropean,British                75.347222  ...  56.896552   60.231023
# GreaterEuropean,WestEuropean,Italian    4.513889  ...   6.896552   11.716172
# GreaterEuropean,WestEuropean,Hispanic   6.250000  ...   5.172414    8.085809
# Asian,IndianSubContinent                2.430556  ...   3.448276    3.300330
# Asian,GreaterEastAsian,EastAsian        3.125000  ...   3.448276    0.990099
# GreaterEuropean,Jewish                  2.430556  ...   1.724138    5.445545
# GreaterEuropean,WestEuropean,French     1.736111  ...   7.758621    4.785479
# GreaterEuropean,EastEuropean            0.694444  ...   0.000000    1.320132
# GreaterAfrican,Muslim                   0.694444  ...   2.586207    1.815182
# GreaterEuropean,WestEuropean,Nordic     0.000000  ...   2.586207    0.330033
# GreaterAfrican,Africans                 0.694444  ...   7.758621    1.320132
# Asian,GreaterEastAsian,Japanese         0.000000  ...   0.862069    0.330033
# GreaterEuropean,WestEuropean,Germanic   2.083333  ...   0.862069    0.330033
#
#                                        north_end  mission_hill  \
# GreaterEuropean,British                51.666667     69.590643
# GreaterEuropean,WestEuropean,Italian   14.444444      2.534113
# GreaterEuropean,WestEuropean,Hispanic   2.222222      1.364522
# Asian,IndianSubContinent                0.555556      5.847953
# Asian,GreaterEastAsian,EastAsian        7.222222      0.389864
# GreaterEuropean,Jewish                  9.444444      2.339181
# GreaterEuropean,WestEuropean,French     5.555556      3.118908
# GreaterEuropean,EastEuropean            0.555556      0.974659
# GreaterAfrican,Muslim                   2.777778     10.136452
# GreaterEuropean,WestEuropean,Nordic     3.333333      0.194932
# GreaterAfrican,Africans                 1.666667      0.000000
# Asian,GreaterEastAsian,Japanese         0.000000      3.313840
# GreaterEuropean,WestEuropean,Germanic   0.555556      0.194932
#
#                                        harbor_islands  west_roxbury  \
# GreaterEuropean,British                     36.363636     71.385238
# GreaterEuropean,WestEuropean,Italian         0.000000      5.965622
# GreaterEuropean,WestEuropean,Hispanic       63.636364      2.022245
# Asian,IndianSubContinent                     0.000000      4.044489
# Asian,GreaterEastAsian,EastAsian             0.000000      1.921132
# GreaterEuropean,Jewish                       0.000000      4.347826
# GreaterEuropean,WestEuropean,French          0.000000      4.954499
# GreaterEuropean,EastEuropean                 0.000000      1.516684
# GreaterAfrican,Muslim                        0.000000      1.718908
# GreaterEuropean,WestEuropean,Nordic          0.000000      1.011122
# GreaterAfrican,Africans                      0.000000      0.606673
# Asian,GreaterEastAsian,Japanese              0.000000      0.303337
# GreaterEuropean,WestEuropean,Germanic        0.000000      0.202224
#
#                                        dorchester    roxbury   mattapan  \
# GreaterEuropean,British                 67.128975  66.494592  68.038741
# GreaterEuropean,WestEuropean,Italian     5.017668   4.547689   6.295400
# GreaterEuropean,WestEuropean,Hispanic    4.787986   2.851524   3.147700
# Asian,IndianSubContinent                 2.897527   4.154376   3.510896
# Asian,GreaterEastAsian,EastAsian         2.826855   2.507375   2.784504
# GreaterEuropean,Jewish                   3.268551   5.408063   5.205811
# GreaterEuropean,WestEuropean,French      8.171378   5.014749   7.506053
# GreaterEuropean,EastEuropean             1.298587   1.007866   0.363196
# GreaterAfrican,Muslim                    1.227915   4.596853   0.484262
# GreaterEuropean,WestEuropean,Nordic      1.298587   0.835792   1.331719
# GreaterAfrican,Africans                  0.812721   1.106195   0.363196
# Asian,GreaterEastAsian,Japanese          0.750883   1.130777   0.847458
# GreaterEuropean,WestEuropean,Germanic    0.512367   0.344149   0.121065
#
#                                        hyde_park
# GreaterEuropean,British                58.169935
# GreaterEuropean,WestEuropean,Italian   14.648212
# GreaterEuropean,WestEuropean,Hispanic   2.960400
# Asian,IndianSubContinent                4.421376
# Asian,GreaterEastAsian,EastAsian        5.536332
# GreaterEuropean,Jewish                  4.536717
# GreaterEuropean,WestEuropean,French     5.728566
# GreaterEuropean,EastEuropean            0.422914
# GreaterAfrican,Muslim                   1.076509
# GreaterEuropean,WestEuropean,Nordic     0.538255
# GreaterAfrican,Africans                 0.422914
# Asian,GreaterEastAsian,Japanese         1.114956
# GreaterEuropean,WestEuropean,Germanic   0.422914
#
# [13 rows x 21 columns]

# %%
agg_df = pd.DataFrame(columns=subs, index=['white', 'black', 'api', 'hispanic'])

# %%
agg_df = agg_df.fillna(0.0)

# %%
pred_races = race_df.index
for sub in subs:
    for each in pred_races:
        temp = race_df.loc[each][sub]
        if each == 'GreaterEuropean,WestEuropean,Hispanic':
            agg_df.loc['hispanic'][sub] += temp
        elif each == 'Asian,GreaterEastAsian,EastAsian' or each == 'Asian,IndianSubContinent' or each == 'Asian,GreaterEastAsian,Japanese':
            agg_df.loc['api'][sub] += temp
        elif each == 'GreaterAfrican,Muslim' or each == 'GreaterAfrican,Africans':
            agg_df.loc['black'][sub] += temp
        else:
            agg_df.loc['white'][sub] += temp

# %%
agg_df.to_csv('Wiki_Last_Name_Race_Representation_by_Neighborhood/2014_representation.csv')

# %%
agg_df
# Out:
#              fenway  beacon_hill   downtown  south_boston  east_boston  \
# white     67.107438    85.310734  82.186235     88.076923    64.155844
# black      1.818182     2.711864   3.238866      2.115385     3.116883
# api       18.842975    10.282486   7.935223      6.692308     3.506494
# hispanic  12.231405     1.694915   6.639676      3.115385    29.220779
#
#            back_bay  jamaica_plain  south_end  charlestown   brighton  ...  \
# white     88.896952      82.827324  90.309278    83.710407  86.805556  ...
# black      3.628447       3.130930   2.783505     6.787330   1.388889  ...
# api        6.168360       7.779886   4.020619     4.072398   5.555556  ...
# hispanic   1.306241       6.261860   2.886598     5.429864   6.250000  ...
#
#            west_end  roslindale  north_end  mission_hill  harbor_islands  \
# white     76.724138   84.158416  85.555556     78.947368       36.363636
# black     10.344828    3.135314   4.444444     10.136452        0.000000
# api        7.758621    4.620462   7.777778      9.551657        0.000000
# hispanic   5.172414    8.085809   2.222222      1.364522       63.636364
#
#           west_roxbury  dorchester    roxbury   mattapan  hyde_park
# white        89.383215   86.696113  83.652901  88.861985  84.467512
# black         2.325581    2.040636   5.703048   0.847458   1.499423
# api           6.268959    6.475265   7.792527   7.142857  11.072664
# hispanic      2.022245    4.787986   2.851524   3.147700   2.960400
#
# [4 rows x 21 columns]
