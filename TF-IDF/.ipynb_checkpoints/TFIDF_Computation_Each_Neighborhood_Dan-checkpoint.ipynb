# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from collections import Counter
from num2words import num2words

import nltk
import os
import string
import numpy as np
import copy
import pandas as pd
import pickle
import re
import math

# %%
import ast

# %% [markdown]
# ## Preprocessing

# %%
def convert_lower_case(data):
    return np.char.lower(data)

def remove_stop_words(data):
    stop_words = stopwords.words('english')
    words = word_tokenize(str(data))
    new_text = ""
    for w in words:
        if w not in stop_words and len(w) > 1:
            new_text = new_text + " " + w
    return new_text

def remove_punctuation(data):
    symbols = "!\"#$%&()*+-./:;<=>?@[\]^_`{|}~\n"
    for i in range(len(symbols)):
        data = np.char.replace(data, symbols[i], ' ')
        data = np.char.replace(data, "  ", " ")
    data = np.char.replace(data, ',', '')
    return data

def remove_apostrophe(data):
    return np.char.replace(data, "'", "")

def stemming(data):
    stemmer= PorterStemmer()
    
    tokens = word_tokenize(str(data))
    new_text = ""
    for w in tokens:
        new_text = new_text + " " + stemmer.stem(w)
    return new_text

def convert_numbers(data):
    tokens = word_tokenize(str(data))
    new_text = ""
    for w in tokens:
        try:
            w = num2words(int(w))
        except:
            a = 0
        new_text = new_text + " " + w
    new_text = np.char.replace(new_text, "-", " ")
    return new_text

def preprocess(data):
    data = convert_lower_case(data)
    data = remove_punctuation(data) #remove comma seperately
    data = remove_apostrophe(data)
    data = remove_stop_words(data)
    data = convert_numbers(data)
    # data = stemming(data)
    data = remove_punctuation(data)
    data = convert_numbers(data)
    # data = stemming(data) #needed again as we need to stem the words
    data = remove_punctuation(data) #needed again as num2word is giving few hypens and commas fourty-one
    data = remove_stop_words(data) #needed again as num2word is giving stop words 101 - one hundred and one
    return data

# %% [markdown]
# ## Creating documents out of the neighborhood-separated articles

# %%
processed_text = []

# %%
df = pd.read_csv('../Entity_Recognition/Neighborhood_Separated_Articles/2018.csv')

# %%
df = df.drop(['Unnamed: 0'], axis=1)
df.head()
# Out:
#                                           dorchester  \
# 0  ('With cyclists agitating for more safety meas...
# 1  ('For the region’s firefighters  this weekend ...
# 2  ('On a bitter cold evening a few days after Ma...
# 3  ('n xa0A two alarm fire damaged an apartment b...
# 4  ('Red Line passengers are facing “severe” dela...
#
#                                              roxbury  \
# 0  ('Born a decade apart  Chuck Berry and Mary Ty...
# 1  ('Late Halloween night  16 year old Gerrod Bro...
# 2  ('Born a decade apart  Chuck Berry and Mary Ty...
# 3  ('Born a decade apart  Chuck Berry and Mary Ty...
# 4  ('Born a decade apart  Chuck Berry and Mary Ty...
#
#                                             mattapan  \
# 0  ('The  that injured 17 passengers on the MBTA’...
# 1  ('Massachusetts is bracing for a fast and furi...
# 2  ('Already off to a rough start to the winter  ...
# 3  ('Heavy snow predicted for eastern Massachuset...
# 4  ('Already off to a rough start to the winter  ...
#
#                                            hyde_park  \
# 0  ('A spout of fire that burst from a gas main o...
# 1  ('A spout of fire that burst from a gas main o...
# 2  ('A spout of fire that burst from a gas main o...
# 3  ('A spout of fire that burst from a gas main o...
# 4  ('A spout of fire that burst from a gas main o...
#
#                                               fenway  \
# 0  ('“Of course — Boston ” That was  after Adam J...
# 1  ('“Of course — Boston ” That was  after Adam J...
# 2  ('No  “Black Panther” isn’t the greatest movie...
# 3  ('No  “Black Panther” isn’t the greatest movie...
# 4  ('“Of course — Boston ” That was  after Adam J...
#
#                                          beacon_hill  \
# 0  ('n  Do it  Blow up the zoning laws that choke...
# 1  ('At a breakfast celebrating Martin Luther Kin...
# 2  ('At a breakfast celebrating Martin Luther Kin...
# 3  ('n  Do it  Blow up the zoning laws that choke...
# 4  ('At a breakfast celebrating Martin Luther Kin...
#
#                                             downtown  \
# 0  ('n nThe idea that bigger is better in health ...
# 1  ('A black maid is chased and slapped on her re...
# 2  ('A black maid is chased and slapped on her re...
# 3  ('FRAMINGHAM — The words carved on the shingle...
# 4  ('One of the most furious winter storms ever m...
#
#                                         south_boston  \
# 0  ('Martin J  Walsh embarked on his second term ...
# 1  ('Martin J  Walsh embarked on his second term ...
# 2  ('Martin J  Walsh embarked on his second term ...
# 3  ('Martin J  Walsh embarked on his second term ...
# 4  ('Boston police arrested two men and recovered...
#
#                                          east_boston  \
# 0  ('Good morning  everyone Thank you to Presiden...
# 1  ('Good morning  everyone Thank you to Presiden...
# 2  ('Good morning  everyone Thank you to Presiden...
# 3  ('As he embarked on his second term  Mayor Mar...
# 4  ('Good morning  everyone Thank you to Presiden...
#
#                                             back_bay  ...  \
# 0  ('The word “mixed” in mixed income housing sho...  ...
# 1  ('The double shooting in Back Bay Saturday nig...  ...
# 2  ('The double shooting in Back Bay Saturday nig...  ...
# 3  ('In a brazen crime  two masked men robbed a r...  ...
# 4  ('In a brazen crime  two masked men robbed a r...  ...
#
#                                          charlestown  \
# 0  ('nMonday  n nOpen at owners’ discretion  n nO...
# 1  ('nMonday n nOpen  nOpen  nOpen  nOpen  nOpen ...
# 2  ('nMonday n nOpen  nOpen  nOpen  nOpen  nOpen ...
# 3  ('A venerable program for busing city children...
# 4  ('A venerable program for busing city children...
#
#                                             brighton  \
# 0  ('Boston police gang unit officers nabbed a 35...
# 1  ('MUSIC n Harmony Tividad and Cleo Tucker’s se...
# 2  ('MUSIC n Harmony Tividad and Cleo Tucker’s se...
# 3  ('If at first you don’t succeed  try  try agai...
# 4  ('If at first you don’t succeed  try  try agai...
#
#                                              allston  \
# 0  ('A five alarm fire heavily damaged a three de...
# 1  ('A five alarm fire heavily damaged a three de...
# 2  ('Dorchester residents who watched an inferno ...
# 3  ('Dorchester residents who watched an inferno ...
# 4  ('Avi Shemtov opened the Chubby Chickpea in Ca...
#
#                                             west_end  \
# 0  ('The father and brother of a beloved youth me...
# 1  ('The smiling young woman took center stage  h...
# 2  ('The smiling young woman took center stage  h...
# 3  ('The father and brother of a beloved youth me...
# 4  ('He wore a blue pinstripe suit to court on Mo...
#
#                                           roslindale  \
# 0  ('And now  the Hub fights back  Boston will li...
# 1  ('No dogs are running at Wonderland Greyhound ...
# 2  ('No dogs are running at Wonderland Greyhound ...
# 3  ('No dogs are running at Wonderland Greyhound ...
# 4  ('No dogs are running at Wonderland Greyhound ...
#
#                                            north_end  \
# 0  ('Deborah Goldberg settles into a chair by the...
# 1  ('A shriveled up Christmas tree long stripped ...
# 2  ('As he zigzags mustard onto a hot dog  actor ...
# 3  ('One of the first responders to the Boston Ma...
# 4  ('The brass bell tolled as the name of each of...
#
#                                         mission_hill  \
# 0  ('A woman who stopped at a gas station to put ...
# 1  ('Here’s something to look forward to  “SUMMER...
# 2  ('A Boston man who turned away from gang life ...
# 3  ('nThe Massachusetts State Police trooper who ...
# 4  ('The Massachusetts State Police trooper who f...
#
#                                       harbor_islands  \
# 0  ('The Columbia Point cut through choppy seas o...
# 1  ('The Columbia Point cut through choppy seas o...
# 2  ('The Columbia Point cut through choppy seas o...
# 3  ('The Columbia Point cut through choppy seas o...
# 4  ('The Columbia Point cut through choppy seas o...
#
#                                longwood_medical_area  \
# 0  ('n of the US bid for the 2024 Olympic Games w...
# 1  ('n of the US bid for the 2024 Olympic Games w...
# 2                            ('no article', 'no_id')
# 3                            ('no article', 'no_id')
# 4                            ('no article', 'no_id')
#
#                                         west_roxbury
# 0  ('The Boston School Committee on Wednesday una...
# 1  ('The Boston School Committee on Wednesday una...
# 2  ('The Boston School Committee on Wednesday una...
# 3  ('n n n    read at 7 p m  at Harvard Book Stor...
# 4  ('The legislator who authored the Massachusett...
#
# [5 rows x 22 columns]

# %%
df = df.fillna("('no article', 'no_id')")
df['dorchester'] = df['dorchester'].apply(ast.literal_eval)
df['roxbury'] = df['roxbury'].apply(ast.literal_eval)
df['mattapan'] = df['mattapan'].apply(ast.literal_eval)
df['hyde_park'] = df['hyde_park'].apply(ast.literal_eval)
df['fenway'] = df['fenway'].apply(ast.literal_eval)
df['beacon_hill'] = df['beacon_hill'].apply(ast.literal_eval)
df['downtown'] = df['downtown'].apply(ast.literal_eval)
df['south_boston'] = df['south_boston'].apply(ast.literal_eval)
df['east_boston'] = df['east_boston'].apply(ast.literal_eval)
df['back_bay'] = df['back_bay'].apply(ast.literal_eval)
df['jamaica_plain'] = df['jamaica_plain'].apply(ast.literal_eval)
df['south_end'] = df['south_end'].apply(ast.literal_eval)
df['charlestown'] = df['charlestown'].apply(ast.literal_eval)
df['brighton'] = df['brighton'].apply(ast.literal_eval)
df['allston'] = df['allston'].apply(ast.literal_eval)
df['west_end'] = df['west_end'].apply(ast.literal_eval)
df['roslindale'] = df['roslindale'].apply(ast.literal_eval)
df['north_end'] = df['north_end'].apply(ast.literal_eval)
df['mission_hill'] = df['mission_hill'].apply(ast.literal_eval)
df['harbor_islands'] = df['harbor_islands'].apply(ast.literal_eval)
df['longwood_medical_area'] = df['longwood_medical_area'].apply(ast.literal_eval)
df['west_roxbury'] = df['west_roxbury'].apply(ast.literal_eval)

# %%
documents = {'hyde_park': [], 'beacon_hill': [], 'south_boston': [], 'jamaica_plain': [], 'east_boston': [],
                'south_end': [], 'back_bay': [], 'north_end': [], 'west_roxbury': [], 'mission_hill': [],
                'harbor_islands': [], 'west_end': [], 'longwood_medical_area': [],
                'dorchester': [], 'roxbury': [], 'downtown': [], 'fenway': [], 'mattapan': [], 'brighton': [],
                'charlestown': [], 'roslindale': [], 'allston': []}

for col in df.columns:
    tokens = []
    for i in range(df.shape[0]):
        article, _ = df.loc[i][col]
        if article != 'no article':
            text = word_tokenize(preprocess(article))
            tokens = tokens + text
    documents[col] = tokens
    print(col + ' DONE')
# Out:
# dorchester DONE
# roxbury DONE
# mattapan DONE
# hyde_park DONE
# fenway DONE
# beacon_hill DONE
# downtown DONE
# south_boston DONE
# east_boston DONE
# back_bay DONE
# jamaica_plain DONE
# south_end DONE
# charlestown DONE
# brighton DONE
# allston DONE
# west_end DONE
# roslindale DONE
# north_end DONE
# mission_hill DONE
# harbor_islands DONE
# longwood_medical_area DONE
# west_roxbury DONE

# %%
processed_text = []
for key in documents:
    processed_text.append(documents[key])

# %%
processed_text
# Out:
# [['spout',
#   'fire',
#   'burst',
#   'gas',
#   'main',
#   'hyde',
#   'park',
#   'avenue',
#   'roslindale',
#   'sunday',
#   'evening',
#   'expected',
#   'burn',
#   'monday',
#   'authorities',
#   'said',
#   'fire',
#   'ten',
#   'inch',
#   'gas',
#   'main',
#   'began',
#   'shortly',
#   'near',
#   'three',
#   'hundred',
#   'forty',
#   'hyde',
#   'park',
#   'ave',
#   'mile',
#   'south',
#   'forest',
#   'hills',
#   'mbta',
#   'station',
#   'fire',
#   'crews',
#   'tried',
#   'use',
#   'sand',
#   'smother',
#   'flames',
#   'steve',
#   'macdonald',
#   'spokesman',
#   'boston',
#   'fire',
#   'department',
#   'said',
#   'national',
#   'grid',
#   'plan',
#   'shut',
#   'gas',
#   'sunday',
#   'night',
#   'extreme',
#   'cold',
#   'meaning',
#   'fire',
#   'likely',
#   'continue',
#   'burn',
#   'try',
#   'shut',
#   'gas',
#   'affect',
#   'hundreds',
#   'households',
#   'thousands',
#   'macdonald',
#   'said',
#   'temperatures',
#   'expected',
#   'drop',
#   'zero',
#   'overnight',
#   'instead',
#   'shutting',
#   'gas',
#   'national',
#   'grid',
#   'plans',
#   'install',
#   'temporary',
#   'bypass',
#   'leak',
#   'effectively',
#   'cutting',
#   'fuel',
#   'fire',
#   'according',
#   'macdonald',
#   'know',
#   'best',
#   'deal',
#   'safe',
#   'manner',
#   'macdonald',
#   'said',
#   'consultation',
#   'city',
#   'officials',
#   'said',
#   'utility',
#   'company',
#   'planning',
#   'install',
#   'bypass',
#   'well',
#   'day',
#   'monday',
#   'meantime',
#   'said',
#   'everything',
#   'contained',
#   'fire',
#   'going',
#   'anywhere',
#   'three',
#   'utility',
#   'workers',
#   'scene',
#   'suffered',
#   'burns',
#   'treated',
#   'transported',
#   'burns',
#   'boston',
#   'emergency',
#   'medical',
#   'service',
#   'according',
#   'tweet',
#   'fire',
#   'department',
#   'three',
#   'three',
#   'decker',
#   'homes',
#   'evacuated',
#   'precaution',
#   'evacuated',
#   'residents',
#   'sheltered',
#   'mbta',
#   'buses',
#   'single',
#   'digit',
#   'weather',
#   'officials',
#   'said',
#   'macdonald',
#   'said',
#   'know',
#   'homes',
#   'would',
#   'evacuated',
#   'already',
#   'evacuated',
#   'would',
#   'able',
#   'return',
#   'said',
#   'red',
#   'cross',
#   'notified',
#   'order',
#   'help',
#   'displaced',
#   'fire',
#   'find',
#   'hotel',
#   'rooms',
#   'spout',
#   'fire',
#   'burst',
#   'gas',
#   'main',
#   'hyde',
#   'park',
#   'avenue',
#   'roslindale',
#   'sunday',
#   'evening',
#   'expected',
#   'burn',
#   'monday',
#   'authorities',
#   'said',
#   'fire',
#   'ten',
#   'inch',
#   'gas',
#   'main',
#   'began',
#   'shortly',
#   'near',
#   'three',
#   'hundred',
#   'forty',
#   'hyde',
#   'park',
#   'ave',
#   'mile',
#   'south',
#   'forest',
#   'hills',
#   'mbta',
#   'station',
#   'fire',
#   'crews',
#   'tried',
#   'use',
#   'sand',
#   'smother',
#   'flames',
#   'steve',
#   'macdonald',
#   'spokesman',
#   'boston',
#   'fire',
#   'department',
#   'said',
#   'national',
#   'grid',
#   'plan',
#   'shut',
#   'gas',
#   'sunday',
#   'night',
#   'extreme',
#   'cold',
#   'meaning',
#   'fire',
#   'likely',
#   'continue',
#   'burn',
#   'try',
#   'shut',
#   'gas',
#   'affect',
#   'hundreds',
#   'households',
#   'thousands',
#   'macdonald',
#   'said',
#   'temperatures',
#   'expected',
#   'drop',
#   'zero',
#   'overnight',
#   'instead',
#   'shutting',
#   'gas',
#   'national',
#   'grid',
#   'plans',
#   'install',
#   'temporary',
#   'bypass',
#   'leak',
#   'effectively',
#   'cutting',
#   'fuel',
#   'fire',
#   'according',
#   'macdonald',
#   'know',
#   'best',
#   'deal',
#   'safe',
#   'manner',
#   'macdonald',
#   'said',
#   'consultation',
#   'city',
#   'officials',
#   'said',
#   'utility',
#   'company',
#   'planning',
#   'install',
#   'bypass',
#   'well',
#   'day',
#   'monday',
#   'meantime',
#   'said',
#   'everything',
#   'contained',
#   'fire',
#   'going',
#   'anywhere',
#   'three',
#   'utility',
#   'workers',
#   'scene',
#   'suffered',
#   'burns',
#   'treated',
#   'transported',
#   'burns',
#   'boston',
#   'emergency',
#   'medical',
#   'service',
#   'according',
#   'tweet',
#   'fire',
#   'department',
#   'three',
#   'three',
#   'decker',
#   'homes',
#   'evacuated',
#   'precaution',
#   'evacuated',
#   'residents',
#   'sheltered',
#   'mbta',
#   'buses',
#   'single',
#   'digit',
#   'weather',
#   'officials',
#   'said',
#   'macdonald',
#   'said',
#   'know',
#   'homes',
#   'would',
#   'evacuated',
#   'already',
#   'evacuated',
#   'would',
#   'able',
#   'return',
#   'said',
#   'red',
#   'cross',
#   'notified',
#   'order',
#   'help',
#   'displaced',
#   'fire',
#   'find',
#   'hotel',
#   'rooms',
#   'spout',
#   'fire',
#   'burst',
#   'gas',
#   'main',
#   'hyde',
#   'park',
#   'avenue',
#   'roslindale',
#   'sunday',
#   'night',
#   'still',
#   'burning',
#   'monday',
#   'crews',
#   'working',
#   'install',
#   'temporary',
#   'bypass',
#   'line',
#   'monday',
#   'afternoon',
#   'according',
#   'fire',
#   'department',
#   'fire',
#   'ten',
#   'inch',
#   'gas',
#   'main',
#   'began',
#   'shortly',
#   'near',
#   'three',
#   'hundred',
#   'forty',
#   'hyde',
#   'park',
#   'ave',
#   'mile',
#   'south',
#   'forest',
#   'hills',
#   'mbta',
#   'station',
#   'fire',
#   'crews',
#   'tried',
#   'use',
#   'sand',
#   'smother',
#   'flames',
#   'fire',
#   'department',
#   'tweeted',
#   'monday',
#   'afternoon',
#   'fire',
#   'would',
#   'ongoing',
#   'least',
#   'today',
#   'crews',
#   'install',
#   'bypass',
#   'effectively',
#   'cut',
#   'fuel',
#   'fire',
#   'shortly',
#   'noon',
#   'work',
#   'crews',
#   'digging',
#   'two',
#   'holes',
#   'street',
#   'temporary',
#   'line',
#   'connected',
#   'according',
#   'fire',
#   'department',
#   'tweets',
#   'crews',
#   'national',
#   'grid',
#   'know',
#   'best',
#   'deal',
#   'safe',
#   'manner',
#   'said',
#   'steve',
#   'macdonald',
#   'spokesman',
#   'boston',
#   'fire',
#   'department',
#   'consultation',
#   'city',
#   'officials',
#   'macdonald',
#   'said',
#   'national',
#   'grid',
#   'shut',
#   'gas',
#   'sunday',
#   'night',
#   'extreme',
#   'cold',
#   'try',
#   'shut',
#   'gas',
#   'affect',
#   'hundreds',
#   'households',
#   'thousands',
#   'macdonald',
#   'said',
#   'monday',
#   'morning',
#   'flames',
#   'still',
#   'shooting',
#   'air',
#   'open',
#   'street',
#   'half',
#   'height',
#   'surrounding',
#   'trees',
#   'work',
#   'crews',
#   'digging',
#   'nearby',
#   'put',
#   'temporary',
#   'line',
#   'reroute',
#   'gas',
#   'national',
#   'grid',
#   'could',
#   'shut',
#   'without',
#   'cutting',
#   'heat',
#   'entire',
#   'street',
#   'sidewalks',
#   'covered',
#   'thick',
#   'sheets',
#   'ice',
#   'firefighters',
#   'sprayed',
#   'water',
#   'heard',
#   'control',
#   'gas',
#   'dangerous',
#   'said',
#   'helen',
#   'loney',
#   'lives',
#   'near',
#   'fire',
#   'feel',
#   'bad',
#   'working',
#   'three',
#   'three',
#   'decker',
#   'homes',
#   'near',
#   'fire',
#   'evacuated',
#   'precaution',
#   'sunday',
#   'night',
#   'neighbors',
#   'said',
#   'worried',
#   'flames',
#   'even',
#   'though',
#   'burning',
#   'night',
#   'boston',
#   'fire',
#   'department',
#   'outstanding',
#   'said',
#   'susan',
#   'lives',
#   'street',
#   'declined',
#   'give',
#   'last',
#   'name',
#   'protect',
#   'privacy',
#   'even',
#   'realized',
#   'fire',
#   'heard',
#   'helicopters',
#   'fire',
#   'engines',
#   'said',
#   'know',
#   'going',
#   'looked',
#   'street',
#   'saw',
#   'huge',
#   'flames',
#   'susan',
#   'loney',
#   'said',
#   'smell',
#   'gas',
#   'thick',
#   'air',
#   'last',
#   'night',
#   'grateful',
#   'evacuated',
#   'still',
#   'heat',
#   'loney',
#   'know',
#   'would',
#   'put',
#   'dog',
#   'cat',
#   'leave',
#   'house',
#   'spent',
#   'night',
#   'watching',
#   'flames',
#   'television',
#   'said',
#   'venture',
#   'see',
#   'person',
#   'curious',
#   'weather',
#   'said',
#   'three',
#   'utility',
#   'workers',
#   'scene',
#   'suffered',
#   'burns',
#   'treated',
#   'transported',
#   'nearby',
#   'hospital',
#   'according',
#   'tweet',
#   'fire',
#   'department',
#   'spout',
#   'fire',
#   'burst',
#   'gas',
#   'main',
#   'hyde',
#   'park',
#   'avenue',
#   'roslindale',
#   'sunday',
#   'night',
#   'still',
#   'burning',
#   'monday',
#   'crews',
#   'working',
#   'install',
#   'temporary',
#   'bypass',
#   'line',
#   'monday',
#   'afternoon',
#   'according',
#   'fire',
#   'department',
#   'fire',
#   'ten',
#   'inch',
#   'gas',
#   'main',
#   'began',
#   'shortly',
#   'near',
#   'three',
#   'hundred',
#   'forty',
#   'hyde',
#   'park',
#   'ave',
#   'mile',
#   'south',
#   'forest',
#   'hills',
#   'mbta',
#   'station',
#   'fire',
#   'crews',
#   'tried',
#   'use',
#   'sand',
#   'smother',
#   'flames',
#   'fire',
#   'department',
#   'tweeted',
#   'monday',
#   'afternoon',
#   'fire',
#   'would',
#   'ongoing',
#   'least',
#   'today',
#   'crews',
#   'install',
#   'bypass',
#   'effectively',
#   'cut',
#   'fuel',
#   'fire',
#   'shortly',
#   'noon',
#   'work',
#   'crews',
#   'digging',
#   'two',
#   'holes',
#   'street',
#   'temporary',
#   'line',
#   'connected',
#   'according',
#   'fire',
#   'department',
#   'tweets',
#   'crews',
#   'national',
#   'grid',
#   'know',
#   'best',
#   'deal',
#   'safe',
#   'manner',
#   'said',
#   'steve',
#   'macdonald',
#   'spokesman',
#   'boston',
#   'fire',
#   'department',
#   'consultation',
#   'city',
#   'officials',
#   'macdonald',
#   'said',
#   'national',
#   'grid',
#   'shut',
#   'gas',
#   'sunday',
#   'night',
#   'extreme',
#   'cold',
#   'try',
#   'shut',
#   'gas',
#   'affect',
#   'hundreds',
#   'households',
#   'thousands',
#   'macdonald',
#   'said',
#   'monday',
#   'morning',
#   'flames',
#   'still',
#   'shooting',
#   'air',
#   'open',
#   'street',
#   'half',
#   'height',
#   'surrounding',
#   'trees',
#   'work',
#   'crews',
#   'digging',
#   'nearby',
#   'put',
#   'temporary',
#   'line',
#   'reroute',
#   'gas',
#   'national',
#   'grid',
#   'could',
#   'shut',
#   'without',
#   'cutting',
#   'heat',
#   'entire',
#   'street',
#   'sidewalks',
#   'covered',
#   'thick',
#   'sheets',
#   'ice',
#   'firefighters',
#   'sprayed',
#   'water',
#   'heard',
#   'control',
#   'gas',
#   'dangerous',
#   'said',
#   'helen',
#   'loney',
#   'lives',
#   'near',
#   'fire',
#   'feel',
#   'bad',
#   'working',
#   'three',
#   'three',
#   'decker',
#   'homes',
#   'near',
#   'fire',
#   'evacuated',
#   'precaution',
#   'sunday',
#   'night',
#   'neighbors',
#   'said',
#   'worried',
#   'flames',
#   'even',
#   'though',
#   'burning',
#   'night',
#   'boston',
#   'fire',
#   'department',
#   'outstanding',
#   'said',
#   'susan',
#   'lives',
#   'street',
#   'declined',
#   'give',
#   'last',
#   'name',
#   'protect',
#   'privacy',
#   'even',
#   'realized',
#   'fire',
#   'heard',
#   'helicopters',
#   'fire',
#   'engines',
#   'said',
#   'know',
#   'going',
#   'looked',
#   'street',
#   'saw',
#   'huge',
#   'flames',
#   'susan',
#   'loney',
#   'said',
#   'smell',
#   'gas',
#   'thick',
#   'air',
#   'last',
#   'night',
#   'grateful',
#   'evacuated',
#   'still',
#   'heat',
#   'loney',
#   'know',
#   'would',
#   'put',
#   'dog',
#   'cat',
#   'leave',
#   'house',
#   'spent',
#   'night',
#   'watching',
#   'flames',
#   'television',
#   'said',
#   'venture',
#   'see',
#   'person',
#   'curious',
#   'weather',
#   'said',
#   'three',
#   'utility',
#   'workers',
#   'scene',
#   'suffered',
#   'burns',
#   'treated',
#   'transported',
#   'nearby',
#   'hospital',
#   'according',
#   'tweet',
#   'fire',
#   'department',
#   'spout',
#   'fire',
#   'burst',
#   'gas',
#   'main',
#   'hyde',
#   'park',
#   'avenue',
#   'roslindale',
#   'sunday',
#   'night',
#   'still',
#   'burning',
#   'monday',
#   'crews',
#   'working',
#   'install',
#   'temporary',
#   'bypass',
#   'line',
#   'monday',
#   'afternoon',
#   'according',
#   'fire',
#   'department',
#   'fire',
#   'ten',
#   'inch',
#   'gas',
#   'main',
#   'began',
#   'shortly',
#   'near',
#   'three',
#   'hundred',
#   'forty',
#   'hyde',
#   'park',
#   'ave',
#   'mile',
#   'south',
#   'forest',
#   'hills',
#   'mbta',
#   'station',
#   'fire',
#   'crews',
#   'tried',
#   'use',
#   'sand',
#   'smother',
#   'flames',
#   'fire',
#   'department',
#   'tweeted',
#   'monday',
#   'afternoon',
#   'fire',
#   'would',
#   'ongoing',
#   'least',
#   'today',
#   'crews',
#   'install',
#   'bypass',
#   'effectively',
#   'cut',
#   'fuel',
#   'fire',
#   'shortly',
#   'noon',
#   'work',
#   'crews',
#   'digging',
#   'two',
#   'holes',
#   'street',
#   'temporary',
#   'line',
#   'connected',
#   'according',
#   'fire',
#   'department',
#   'tweets',
#   'crews',
#   'national',
#   'grid',
#   'know',
#   'best',
#   'deal',
#   'safe',
#   'manner',
#   'said',
#   'steve',
#   'macdonald',
#   'spokesman',
#   'boston',
#   'fire',
#   'department',
#   'consultation',
#   'city',
#   'officials',
#   'macdonald',
#   'said',
#   'national',
#   'grid',
#   'shut',
#   'gas',
#   'sunday',
#   'night',
#   'extreme',
#   'cold',
#   'try',
#   'shut',
#   'gas',
#   'affect',
#   'hundreds',
#   'households',
#   ...],
#  ['blow',
#   'zoning',
#   'laws',
#   'choke',
#   'new',
#   'housing',
#   'force',
#   'college',
#   'professors',
#   'live',
#   'cars',
#   'state',
#   'senator',
#   'san',
#   'francisco',
#   'recently',
#   'filed',
#   'minimum',
#   'parking',
#   'requirements',
#   'limits',
#   'density',
#   'certain',
#   'restrictions',
#   'residential',
#   'housing',
#   'construction',
#   'within',
#   'half',
#   'mile',
#   'train',
#   'station',
#   'quarter',
#   'mile',
#   'stops',
#   'high',
#   'frequency',
#   'bus',
#   'routes',
#   'senator',
#   'scott',
#   'wiener',
#   'bill',
#   'would',
#   'promote',
#   'bigger',
#   'taller',
#   'new',
#   'buildings',
#   'transit',
#   'rich',
#   'urban',
#   'areas',
#   'across',
#   'california',
#   'bill',
#   'may',
#   'biggest',
#   'environmental',
#   'boon',
#   'best',
#   'job',
#   'creator',
#   'greatest',
#   'strike',
#   'inequality',
#   'anyone',
#   'proposed',
#   'united',
#   'states',
#   'decades',
#   'ease',
#   'zoning',
#   'limits',
#   'private',
#   'developers',
#   'money',
#   'create',
#   'millions',
#   'new',
#   'units',
#   'urban',
#   'areas',
#   'absorbing',
#   'influx',
#   'tech',
#   'finance',
#   'bros',
#   'freeing',
#   'homes',
#   'everyone',
#   'else',
#   'creating',
#   'lots',
#   'construction',
#   'jobs',
#   'along',
#   'way',
#   'make',
#   'room',
#   'people',
#   'world',
#   'economically',
#   'productive',
#   'metro',
#   'areas',
#   'thriving',
#   'cities',
#   'need',
#   'room',
#   'grow',
#   'according',
#   'two',
#   'thirds',
#   'homes',
#   'san',
#   'francisco',
#   'valued',
#   'million',
#   'twenty',
#   'two',
#   'percent',
#   'since',
#   'two',
#   'thousand',
#   'twelve',
#   'boston',
#   'area',
#   'situation',
#   'dire',
#   'yet',
#   'percentage',
#   'homes',
#   'million',
#   'dollar',
#   'values',
#   'five',
#   'years',
#   'rare',
#   'event',
#   'wiener',
#   'bill',
#   'passes',
#   'might',
#   'persuade',
#   'pricey',
#   'enclaves',
#   'around',
#   'country',
#   'including',
#   'eastern',
#   'massachusetts',
#   'cure',
#   'housing',
#   'crisis',
#   'complex',
#   'recently',
#   'governor',
#   'charlie',
#   'baker',
#   'including',
#   'grant',
#   'program',
#   'cities',
#   'towns',
#   'ease',
#   'zoning',
#   'plus',
#   'modest',
#   'legislation',
#   'would',
#   'allow',
#   'local',
#   'government',
#   'bodies',
#   'approve',
#   'denser',
#   'home',
#   'construction',
#   'simple',
#   'majority',
#   'rather',
#   'two',
#   'thirds',
#   'vote',
#   'efforts',
#   'beacon',
#   'hill',
#   'instance',
#   'designating',
#   'areas',
#   'developers',
#   'build',
#   'housing',
#   'without',
#   'seeking',
#   'special',
#   'permission',
#   'giving',
#   'people',
#   'freer',
#   'rein',
#   'carve',
#   'granny',
#   'apartments',
#   'existing',
#   'houses',
#   'progress',
#   'slow',
#   'house',
#   'particular',
#   'protected',
#   'ability',
#   'cities',
#   'towns',
#   'say',
#   'meanwhile',
#   'even',
#   'people',
#   'consider',
#   'housing',
#   'advocates',
#   'thrall',
#   'left',
#   'wing',
#   'version',
#   'climate',
#   'change',
#   'denial',
#   'belief',
#   'building',
#   'units',
#   'pushes',
#   'prices',
#   'last',
#   'year',
#   'state',
#   'democratic',
#   'convention',
#   'band',
#   'progressives',
#   'tried',
#   'blessedly',
#   'failed',
#   'change',
#   'party',
#   'platform',
#   'rule',
#   'thumb',
#   'plan',
#   'lower',
#   'housing',
#   'costs',
#   'depends',
#   'overthrowing',
#   'laws',
#   'capitalism',
#   'plan',
#   'california',
#   'predictably',
#   'shilling',
#   'developers',
#   'imaginatively',
#   'bill',
#   'serves',
#   'white',
#   'supremacist',
#   'agenda',
#   'suggestion',
#   'today',
#   'zoning',
#   'promotes',
#   'equity',
#   'nothing',
#   'short',
#   'astonishing',
#   'zoning',
#   'ugly',
#   'history',
#   'startling',
#   'book',
#   'entitled',
#   'color',
#   'law',
#   'forgotten',
#   'history',
#   'government',
#   'segregated',
#   'america',
#   'author',
#   'richard',
#   'rothstein',
#   'federal',
#   'state',
#   'local',
#   'officials',
#   'took',
#   'decades',
#   'keep',
#   'african',
#   'americans',
#   'moving',
#   'white',
#   'areas',
#   'courts',
#   'invalidated',
#   'explicit',
#   'racial',
#   'zoning',
#   'cities',
#   'towns',
#   'coast',
#   'coast',
#   'restricted',
#   'construction',
#   'multifamily',
#   'housing',
#   'legally',
#   'defensible',
#   'way',
#   'keep',
#   'supposed',
#   'undesirables',
#   'today',
#   'justify',
#   'zoning',
#   'way',
#   'protecting',
#   'schools',
#   'homes',
#   'slaughterhouses',
#   'chemical',
#   'plants',
#   'fair',
#   'enough',
#   'long',
#   'ago',
#   'vanquished',
#   'genuine',
#   'nuisances',
#   'upscale',
#   'homeowners',
#   'moved',
#   'fighting',
#   'threats',
#   'like',
#   'height',
#   'shadows',
#   'people',
#   'offered',
#   'chance',
#   'tell',
#   'people',
#   'property',
#   'tempting',
#   'turn',
#   'many',
#   'beloved',
#   'neighborhoods',
#   'boston',
#   'area',
#   'built',
#   'advent',
#   'zoning',
#   'need',
#   'develop',
#   'nicely',
#   'neighborhood',
#   'groups',
#   'decide',
#   'stricter',
#   'better',
#   'hard',
#   'stop',
#   'vast',
#   'areas',
#   'greater',
#   'boston',
#   'california',
#   'housing',
#   'problems',
#   'like',
#   'population',
#   'growth',
#   'far',
#   'faster',
#   'many',
#   'land',
#   'use',
#   'laws',
#   'stricter',
#   'result',
#   'housing',
#   'prices',
#   'spiraled',
#   'much',
#   'farther',
#   'control',
#   'upside',
#   'government',
#   'legalizes',
#   'housing',
#   'construction',
#   'housing',
#   'market',
#   'respond',
#   'quickly',
#   'year',
#   'since',
#   'california',
#   'eased',
#   'restrictions',
#   'granny',
#   'flats',
#   'number',
#   'applications',
#   'build',
#   'units',
#   'los',
#   'angeles',
#   'golden',
#   'state',
#   'chance',
#   'something',
#   'far',
#   'bolder',
#   'come',
#   'california',
#   'shy',
#   'breakfast',
#   'celebrating',
#   'martin',
#   'luther',
#   'king',
#   'jr',
#   'top',
#   'massachusetts',
#   'politicians',
#   'monday',
#   'pilloried',
#   'president',
#   'trump',
#   'calling',
#   'racist',
#   'bully',
#   'said',
#   'words',
#   'actions',
#   'tarnish',
#   'magnanimous',
#   'values',
#   'animated',
#   'generations',
#   'americans',
#   'pledged',
#   'battle',
#   'new',
#   'york',
#   'billionaire',
#   'anti',
#   'trump',
#   'jeremiads',
#   'came',
#   'amid',
#   'roiling',
#   'national',
#   'debate',
#   'president',
#   'feelings',
#   'people',
#   'color',
#   'delivered',
#   'days',
#   'united',
#   'states',
#   'accepting',
#   'immigrants',
#   'shithole',
#   'countries',
#   'including',
#   'haiti',
#   'el',
#   'salvador',
#   'african',
#   'nations',
#   'rather',
#   'places',
#   'like',
#   'norway',
#   'face',
#   'challenge',
#   'openly',
#   'racist',
#   'president',
#   'united',
#   'states',
#   'said',
#   'senator',
#   'elizabeth',
#   'warren',
#   'applause',
#   'south',
#   'boston',
#   'main',
#   'convention',
#   'center',
#   'donald',
#   'trump',
#   'racist',
#   'bully',
#   'know',
#   'deal',
#   'bullies',
#   'back',
#   'shut',
#   'fight',
#   'back',
#   'nsenator',
#   'edward',
#   'markey',
#   'speech',
#   'brought',
#   'crowd',
#   'hundreds',
#   'feet',
#   'said',
#   'embarrassed',
#   'hard',
#   'work',
#   'ambition',
#   'vision',
#   'immigrants',
#   'come',
#   'united',
#   'states',
#   'seeking',
#   'better',
#   'life',
#   'bringing',
#   'unique',
#   'knowledge',
#   'culture',
#   'skills',
#   'embarrassed',
#   'donald',
#   'trump',
#   'racist',
#   'attitudes',
#   'comments',
#   'malden',
#   'democrat',
#   'said',
#   'would',
#   'dr',
#   'king',
#   'expect',
#   'us',
#   'face',
#   'disregard',
#   'basic',
#   'decency',
#   'believe',
#   'dr',
#   'king',
#   'would',
#   'want',
#   'us',
#   'fight',
#   'nasked',
#   'sunday',
#   'answers',
#   'people',
#   'say',
#   'racist',
#   'racist',
#   'least',
#   'racist',
#   'person',
#   'ever',
#   'interviewed',
#   'tell',
#   'monday',
#   'trump',
#   'spent',
#   'hours',
#   'trump',
#   'international',
#   'golf',
#   'course',
#   'florida',
#   'boston',
#   'breakfast',
#   'governor',
#   'charlie',
#   'baker',
#   'also',
#   'took',
#   'aim',
#   'president',
#   'without',
#   'mentioning',
#   'name',
#   'echoing',
#   'king',
#   'imperative',
#   'speak',
#   'injustice',
#   'baker',
#   'recalled',
#   'quote',
#   'civil',
#   'rights',
#   'leader',
#   'comes',
#   'time',
#   'silence',
#   'betrayal',
#   'governor',
#   'swampscott',
#   'republican',
#   'running',
#   'election',
#   'year',
#   'spoke',
#   'late',
#   'mother',
#   'struggle',
#   'alzheimer',
#   'final',
#   'years',
#   'nursing',
#   'home',
#   'time',
#   'said',
#   'majority',
#   'people',
#   'took',
#   'care',
#   'mom',
#   'africa',
#   'haiti',
#   'hailed',
#   'men',
#   'women',
#   'kind',
#   'thoughtful',
#   'positive',
#   'said',
#   'lifted',
#   'family',
#   'time',
#   'immense',
#   'pain',
#   'would',
#   'demean',
#   'insult',
#   'bring',
#   'others',
#   'simply',
#   'different',
#   'simple',
#   'message',
#   'baker',
#   'said',
#   'country',
#   'great',
#   'diversity',
#   'spite',
#   'nattorney',
#   'general',
#   'maura',
#   'healey',
#   'called',
#   'audience',
#   'take',
#   'long',
#   'view',
#   'toward',
#   'justice',
#   'rather',
#   'short',
#   'view',
#   'toward',
#   'next',
#   'tweet',
#   'news',
#   'cycle',
#   'nhealey',
#   'democrat',
#   'said',
#   'people',
#   'may',
#   'feel',
#   'threatened',
#   'challenged',
#   'forces',
#   'corrosive',
#   'corrupting',
#   'coarsening',
#   'state',
#   'top',
#   'law',
#   'enforcement',
#   'official',
#   'quoted',
#   'book',
#   'isaiah',
#   'u2009',
#   'run',
#   'grow',
#   'weary',
#   'walk',
#   'faint',
#   'said',
#   'let',
#   'us',
#   'brothers',
#   'sisters',
#   'faint',
#   'time',
#   'politicians',
#   'spoke',
#   'issues',
#   'closer',
#   'home',
#   'state',
#   'senator',
#   'sonia',
#   'chang',
#   'díaz',
#   'jamaica',
#   'plain',
#   'democrat',
#   'cheered',
#   'forward',
#   'movement',
#   'wide',
#   'ranging',
#   'criminal',
#   'justice',
#   'bill',
#   'beacon',
#   'hill',
#   'animating',
#   'theme',
#   'boston',
#   'event',
#   '48th',
#   'annual',
#   'breakfast',
#   'commemoration',
#   'king',
#   'city',
#   'implicitly',
#   'explicity',
#   'fight',
#   'trump',
#   'representative',
#   'jeffrey',
#   'sánchez',
#   'boston',
#   'democrat',
#   'said',
#   'national',
#   'discourse',
#   'reminds',
#   'us',
#   'every',
#   'tweet',
#   'continue',
#   'rally',
#   'love',
#   'friends',
#   'know',
#   'time',
#   'boston',
#   'mayor',
#   'martin',
#   'walsh',
#   'told',
#   'crowd',
#   'king',
#   'legacy',
#   'stronger',
#   'ever',
#   'words',
#   'values',
#   'needed',
#   'ever',
#   'warren',
#   'cambridge',
#   'democrat',
#   'seen',
#   'potential',
#   'candidate',
#   'president',
#   'two',
#   'thousand',
#   'twenty',
#   'hammered',
#   'home',
#   'point',
#   'referring',
#   'trump',
#   'alleged',
#   'remarks',
#   'immigration',
#   'response',
#   'violent',
#   'rally',
#   'charlottesville',
#   'virginia',
#   'last',
#   'summer',
#   'racist',
#   'bully',
#   'talks',
#   'people',
#   'march',
#   'white',
#   'supremacists',
#   'nazis',
#   'fine',
#   'people',
#   'warren',
#   'said',
#   'refers',
#   'shithole',
#   'countries',
#   'africa',
#   'uses',
#   'hateful',
#   'rhetoric',
#   'push',
#   'discrimination',
#   'america',
#   'better',
#   'believe',
#   'fight',
#   'back',
#   'rhetorical',
#   'thrusts',
#   'president',
#   'brought',
#   'quick',
#   'response',
#   'two',
#   'us',
#   'senate',
#   'opponents',
#   'republicans',
#   'geoff',
#   'diehl',
#   'state',
#   'representative',
#   'john',
#   'kingston',
#   'businessman',
#   'diehl',
#   'dinged',
#   'framed',
#   'warren',
#   'divisive',
#   'remarks',
#   'including',
#   'use',
#   'expletive',
#   'intended',
#   'shock',
#   'value',
#   'kingston',
#   'said',
#   'senator',
#   'toxic',
#   'message',
#   'division',
#   'could',
#   'step',
#   'legacy',
#   'dr',
#   'king',
#   'warren',
#   'however',
#   'sought',
#   'reflect',
#   'king',
#   'vision',
#   'tap',
#   'churning',
#   'dismay',
#   'president',
#   'words',
#   'policies',
#   'fights',
#   'tough',
#   'get',
#   'fight',
#   'warren',
#   'said',
#   'know',
#   'resist',
#   'persist',
#   'overcome',
#   'breakfast',
#   'celebrating',
#   'martin',
#   'luther',
#   'king',
#   'jr',
#   'top',
#   'massachusetts',
#   'politicians',
#   'monday',
#   'pilloried',
#   'president',
#   'trump',
#   'calling',
#   'racist',
#   'bully',
#   'said',
#   'words',
#   'actions',
#   'tarnish',
#   'magnanimous',
#   'values',
#   'animated',
#   'generations',
#   'americans',
#   'pledged',
#   'battle',
#   'new',
#   'york',
#   'billionaire',
#   'anti',
#   'trump',
#   'jeremiads',
#   'came',
#   'amid',
#   'roiling',
#   'national',
#   'debate',
#   'president',
#   'feelings',
#   'people',
#   'color',
#   'delivered',
#   'days',
#   'united',
#   'states',
#   'accepting',
#   'immigrants',
#   'shithole',
#   'countries',
#   'including',
#   'haiti',
#   'el',
#   'salvador',
#   'african',
#   'nations',
#   'rather',
#   'places',
#   'like',
#   'norway',
#   'face',
#   'challenge',
#   'openly',
#   'racist',
#   'president',
#   'united',
#   'states',
#   'said',
#   'senator',
#   'elizabeth',
#   'warren',
#   'applause',
#   'south',
#   'boston',
#   'main',
#   'convention',
#   'center',
#   'donald',
#   'trump',
#   'racist',
#   'bully',
#   'know',
#   'deal',
#   'bullies',
#   'back',
#   'shut',
#   'fight',
#   'back',
#   'nsenator',
#   'edward',
#   'markey',
#   'speech',
#   'brought',
#   'crowd',
#   'hundreds',
#   'feet',
#   'said',
#   ...],
#  ['martin',
#   'walsh',
#   'embarked',
#   'second',
#   'term',
#   'boston',
#   '54th',
#   'mayor',
#   'monday',
#   'morning',
#   'promising',
#   'inauguration',
#   'rebuild',
#   'city',
#   'middle',
#   'class',
#   'ensure',
#   'boston',
#   'serves',
#   'beacon',
#   'rest',
#   'nation',
#   'front',
#   'crowd',
#   'hundreds',
#   'cutler',
#   'majestic',
#   'theatre',
#   'frigid',
#   'new',
#   'year',
#   'day',
#   'morning',
#   'walsh',
#   'also',
#   'vowed',
#   'rebuild',
#   'long',
#   'island',
#   'bridge',
#   'said',
#   'play',
#   'vital',
#   'role',
#   'boston',
#   'recovery',
#   'landscape',
#   'today',
#   'pledge',
#   'rebuild',
#   'bridge',
#   'walsh',
#   'said',
#   'create',
#   'long',
#   'island',
#   'comprehensive',
#   'long',
#   'term',
#   'recovery',
#   'campus',
#   'city',
#   'state',
#   'need',
#   'ever',
#   'tackle',
#   'opioid',
#   'crisis',
#   'speech',
#   'walsh',
#   'said',
#   'focus',
#   'next',
#   'four',
#   'years',
#   'core',
#   'issues',
#   'affecting',
#   'middle',
#   'class',
#   'including',
#   'education',
#   'housing',
#   'rebuilding',
#   'neighborhoods',
#   'much',
#   'twenty',
#   'minute',
#   'speech',
#   'concentrated',
#   'improving',
#   'education',
#   'addressing',
#   'chronic',
#   'homelessness',
#   'city',
#   'world',
#   'class',
#   'works',
#   'middle',
#   'class',
#   'walsh',
#   'said',
#   'thunderous',
#   'applause',
#   'walsh',
#   'sworn',
#   'supreme',
#   'judicial',
#   'court',
#   'justice',
#   'kimberly',
#   'budd',
#   'former',
#   'vice',
#   'president',
#   'joseph',
#   'biden',
#   'jr',
#   'called',
#   'walsh',
#   'best',
#   'mayor',
#   'entire',
#   'united',
#   'states',
#   'america',
#   'mayor',
#   'never',
#   'forget',
#   'came',
#   'reason',
#   'sought',
#   'position',
#   'first',
#   'place',
#   'biden',
#   'said',
#   'adding',
#   'match',
#   'made',
#   'heaven',
#   'marty',
#   'walsh',
#   'boston',
#   'boston',
#   'celebrate',
#   'four',
#   'hundred',
#   'year',
#   'anniversary',
#   'four',
#   'years',
#   'walsh',
#   'said',
#   'goal',
#   'laid',
#   'imagine',
#   'boston',
#   'two',
#   'thousand',
#   'thirty',
#   'plan',
#   'prepare',
#   'city',
#   'next',
#   'century',
#   'one',
#   'greatest',
#   'cities',
#   'world',
#   'nearly',
#   'four',
#   'centuries',
#   'greatest',
#   'days',
#   'yet',
#   'come',
#   'mayor',
#   'said',
#   'walsh',
#   'later',
#   'swore',
#   'thirteen',
#   'members',
#   'city',
#   'council',
#   'including',
#   'newly',
#   'elected',
#   'lydia',
#   'edwards',
#   'lawyer',
#   'represent',
#   'east',
#   'boston',
#   'charlestown',
#   'north',
#   'end',
#   'ed',
#   'flynn',
#   'navy',
#   'veteran',
#   'probation',
#   'officer',
#   'whose',
#   'district',
#   'stretches',
#   'south',
#   'boston',
#   'south',
#   'end',
#   'kim',
#   'janey',
#   'whose',
#   'district',
#   'makes',
#   'much',
#   'roxbury',
#   'martin',
#   'walsh',
#   'embarked',
#   'second',
#   'term',
#   'boston',
#   '54th',
#   'mayor',
#   'monday',
#   'morning',
#   'promising',
#   'inauguration',
#   'rebuild',
#   'city',
#   'middle',
#   'class',
#   'ensure',
#   'boston',
#   'serves',
#   'beacon',
#   'rest',
#   'nation',
#   'front',
#   'crowd',
#   'hundreds',
#   'cutler',
#   'majestic',
#   'theatre',
#   'frigid',
#   'new',
#   'year',
#   'day',
#   'morning',
#   'walsh',
#   'also',
#   'vowed',
#   'rebuild',
#   'long',
#   'island',
#   'bridge',
#   'said',
#   'play',
#   'vital',
#   'role',
#   'boston',
#   'recovery',
#   'landscape',
#   'today',
#   'pledge',
#   'rebuild',
#   'bridge',
#   'walsh',
#   'said',
#   'create',
#   'long',
#   'island',
#   'comprehensive',
#   'long',
#   'term',
#   'recovery',
#   'campus',
#   'city',
#   'state',
#   'need',
#   'ever',
#   'tackle',
#   'opioid',
#   'crisis',
#   'speech',
#   'walsh',
#   'said',
#   'focus',
#   'next',
#   'four',
#   'years',
#   'core',
#   'issues',
#   'affecting',
#   'middle',
#   'class',
#   'including',
#   'education',
#   'housing',
#   'rebuilding',
#   'neighborhoods',
#   'much',
#   'twenty',
#   'minute',
#   'speech',
#   'concentrated',
#   'improving',
#   'education',
#   'addressing',
#   'chronic',
#   'homelessness',
#   'city',
#   'world',
#   'class',
#   'works',
#   'middle',
#   'class',
#   'walsh',
#   'said',
#   'thunderous',
#   'applause',
#   'walsh',
#   'sworn',
#   'supreme',
#   'judicial',
#   'court',
#   'justice',
#   'kimberly',
#   'budd',
#   'former',
#   'vice',
#   'president',
#   'joseph',
#   'biden',
#   'jr',
#   'called',
#   'walsh',
#   'best',
#   'mayor',
#   'entire',
#   'united',
#   'states',
#   'america',
#   'mayor',
#   'never',
#   'forget',
#   'came',
#   'reason',
#   'sought',
#   'position',
#   'first',
#   'place',
#   'biden',
#   'said',
#   'adding',
#   'match',
#   'made',
#   'heaven',
#   'marty',
#   'walsh',
#   'boston',
#   'boston',
#   'celebrate',
#   'four',
#   'hundred',
#   'year',
#   'anniversary',
#   'four',
#   'years',
#   'walsh',
#   'said',
#   'goal',
#   'laid',
#   'imagine',
#   'boston',
#   'two',
#   'thousand',
#   'thirty',
#   'plan',
#   'prepare',
#   'city',
#   'next',
#   'century',
#   'one',
#   'greatest',
#   'cities',
#   'world',
#   'nearly',
#   'four',
#   'centuries',
#   'greatest',
#   'days',
#   'yet',
#   'come',
#   'mayor',
#   'said',
#   'walsh',
#   'later',
#   'swore',
#   'thirteen',
#   'members',
#   'city',
#   'council',
#   'including',
#   'newly',
#   'elected',
#   'lydia',
#   'edwards',
#   'lawyer',
#   'represent',
#   'east',
#   'boston',
#   'charlestown',
#   'north',
#   'end',
#   'ed',
#   'flynn',
#   'navy',
#   'veteran',
#   'probation',
#   'officer',
#   'whose',
#   'district',
#   'stretches',
#   'south',
#   'boston',
#   'south',
#   'end',
#   'kim',
#   'janey',
#   'whose',
#   'district',
#   'makes',
#   'much',
#   'roxbury',
#   'martin',
#   'walsh',
#   'embarked',
#   'second',
#   'term',
#   'boston',
#   '54th',
#   'mayor',
#   'monday',
#   'morning',
#   'promising',
#   'inauguration',
#   'rebuild',
#   'city',
#   'middle',
#   'class',
#   'ensure',
#   'boston',
#   'serves',
#   'beacon',
#   'rest',
#   'nation',
#   'front',
#   'crowd',
#   'hundreds',
#   'cutler',
#   'majestic',
#   'theatre',
#   'frigid',
#   'new',
#   'year',
#   'day',
#   'morning',
#   'walsh',
#   'also',
#   'vowed',
#   'rebuild',
#   'long',
#   'island',
#   'bridge',
#   'said',
#   'play',
#   'vital',
#   'role',
#   'boston',
#   'recovery',
#   'landscape',
#   'today',
#   'pledge',
#   'rebuild',
#   'bridge',
#   'walsh',
#   'said',
#   'create',
#   'long',
#   'island',
#   'comprehensive',
#   'long',
#   'term',
#   'recovery',
#   'campus',
#   'city',
#   'state',
#   'need',
#   'ever',
#   'tackle',
#   'opioid',
#   'crisis',
#   'speech',
#   'walsh',
#   'said',
#   'focus',
#   'next',
#   'four',
#   'years',
#   'core',
#   'issues',
#   'affecting',
#   'middle',
#   'class',
#   'including',
#   'education',
#   'housing',
#   'rebuilding',
#   'neighborhoods',
#   'much',
#   'twenty',
#   'minute',
#   'speech',
#   'concentrated',
#   'improving',
#   'education',
#   'addressing',
#   'chronic',
#   'homelessness',
#   'city',
#   'world',
#   'class',
#   'works',
#   'middle',
#   'class',
#   'walsh',
#   'said',
#   'thunderous',
#   'applause',
#   'walsh',
#   'sworn',
#   'supreme',
#   'judicial',
#   'court',
#   'justice',
#   'kimberly',
#   'budd',
#   'former',
#   'vice',
#   'president',
#   'joseph',
#   'biden',
#   'jr',
#   'called',
#   'walsh',
#   'best',
#   'mayor',
#   'entire',
#   'united',
#   'states',
#   'america',
#   'mayor',
#   'never',
#   'forget',
#   'came',
#   'reason',
#   'sought',
#   'position',
#   'first',
#   'place',
#   'biden',
#   'said',
#   'adding',
#   'match',
#   'made',
#   'heaven',
#   'marty',
#   'walsh',
#   'boston',
#   'boston',
#   'celebrate',
#   'four',
#   'hundred',
#   'year',
#   'anniversary',
#   'four',
#   'years',
#   'walsh',
#   'said',
#   'goal',
#   'laid',
#   'imagine',
#   'boston',
#   'two',
#   'thousand',
#   'thirty',
#   'plan',
#   'prepare',
#   'city',
#   'next',
#   'century',
#   'one',
#   'greatest',
#   'cities',
#   'world',
#   'nearly',
#   'four',
#   'centuries',
#   'greatest',
#   'days',
#   'yet',
#   'come',
#   'mayor',
#   'said',
#   'walsh',
#   'later',
#   'swore',
#   'thirteen',
#   'members',
#   'city',
#   'council',
#   'including',
#   'newly',
#   'elected',
#   'lydia',
#   'edwards',
#   'lawyer',
#   'represent',
#   'east',
#   'boston',
#   'charlestown',
#   'north',
#   'end',
#   'ed',
#   'flynn',
#   'navy',
#   'veteran',
#   'probation',
#   'officer',
#   'whose',
#   'district',
#   'stretches',
#   'south',
#   'boston',
#   'south',
#   'end',
#   'kim',
#   'janey',
#   'whose',
#   'district',
#   'makes',
#   'much',
#   'roxbury',
#   'martin',
#   'walsh',
#   'embarked',
#   'second',
#   'term',
#   'boston',
#   '54th',
#   'mayor',
#   'monday',
#   'morning',
#   'promising',
#   'inauguration',
#   'rebuild',
#   'city',
#   'middle',
#   'class',
#   'ensure',
#   'boston',
#   'serves',
#   'beacon',
#   'rest',
#   'nation',
#   'front',
#   'crowd',
#   'hundreds',
#   'cutler',
#   'majestic',
#   'theatre',
#   'frigid',
#   'new',
#   'year',
#   'day',
#   'morning',
#   'walsh',
#   'also',
#   'vowed',
#   'rebuild',
#   'long',
#   'island',
#   'bridge',
#   'said',
#   'play',
#   'vital',
#   'role',
#   'boston',
#   'recovery',
#   'landscape',
#   'today',
#   'pledge',
#   'rebuild',
#   'bridge',
#   'walsh',
#   'said',
#   'create',
#   'long',
#   'island',
#   'comprehensive',
#   'long',
#   'term',
#   'recovery',
#   'campus',
#   'city',
#   'state',
#   'need',
#   'ever',
#   'tackle',
#   'opioid',
#   'crisis',
#   'speech',
#   'walsh',
#   'said',
#   'focus',
#   'next',
#   'four',
#   'years',
#   'core',
#   'issues',
#   'affecting',
#   'middle',
#   'class',
#   'including',
#   'education',
#   'housing',
#   'rebuilding',
#   'neighborhoods',
#   'much',
#   'twenty',
#   'minute',
#   'speech',
#   'concentrated',
#   'improving',
#   'education',
#   'addressing',
#   'chronic',
#   'homelessness',
#   'city',
#   'world',
#   'class',
#   'works',
#   'middle',
#   'class',
#   'walsh',
#   'said',
#   'thunderous',
#   'applause',
#   'walsh',
#   'sworn',
#   'supreme',
#   'judicial',
#   'court',
#   'justice',
#   'kimberly',
#   'budd',
#   'former',
#   'vice',
#   'president',
#   'joseph',
#   'biden',
#   'jr',
#   'called',
#   'walsh',
#   'best',
#   'mayor',
#   'entire',
#   'united',
#   'states',
#   'america',
#   'mayor',
#   'never',
#   'forget',
#   'came',
#   'reason',
#   'sought',
#   'position',
#   'first',
#   'place',
#   'biden',
#   'said',
#   'adding',
#   'match',
#   'made',
#   'heaven',
#   'marty',
#   'walsh',
#   'boston',
#   'boston',
#   'celebrate',
#   'four',
#   'hundred',
#   'year',
#   'anniversary',
#   'four',
#   'years',
#   'walsh',
#   'said',
#   'goal',
#   'laid',
#   'imagine',
#   'boston',
#   'two',
#   'thousand',
#   'thirty',
#   'plan',
#   'prepare',
#   'city',
#   'next',
#   'century',
#   'one',
#   'greatest',
#   'cities',
#   'world',
#   'nearly',
#   'four',
#   'centuries',
#   'greatest',
#   'days',
#   'yet',
#   'come',
#   'mayor',
#   'said',
#   'walsh',
#   'later',
#   'swore',
#   'thirteen',
#   'members',
#   'city',
#   'council',
#   'including',
#   'newly',
#   'elected',
#   'lydia',
#   'edwards',
#   'lawyer',
#   'represent',
#   'east',
#   'boston',
#   'charlestown',
#   'north',
#   'end',
#   'ed',
#   'flynn',
#   'navy',
#   'veteran',
#   'probation',
#   'officer',
#   'whose',
#   'district',
#   'stretches',
#   'south',
#   'boston',
#   'south',
#   'end',
#   'kim',
#   'janey',
#   'whose',
#   'district',
#   'makes',
#   'much',
#   'roxbury',
#   'boston',
#   'police',
#   'arrested',
#   'two',
#   'men',
#   'recovered',
#   'illegal',
#   'firearm',
#   'drugs',
#   'vehicle',
#   'south',
#   'boston',
#   'tuesday',
#   'afternoon',
#   'christian',
#   'baez',
#   'twenty',
#   'six',
#   'dorchester',
#   'wilden',
#   'suazo',
#   'twenty',
#   'nine',
#   'mattapan',
#   'arrested',
#   'charged',
#   'unlawful',
#   'possession',
#   'firearm',
#   'unlawful',
#   'possession',
#   'ammunition',
#   'unlawfully',
#   'carrying',
#   'loaded',
#   'firearm',
#   'unlawful',
#   'possession',
#   'large',
#   'capacity',
#   'feeding',
#   'device',
#   'possession',
#   'intent',
#   'distribute',
#   'class',
#   'drug',
#   'marijuana',
#   'according',
#   'press',
#   'release',
#   'bpdnews',
#   'com',
#   'police',
#   'said',
#   'baez',
#   'suazo',
#   'seen',
#   'driving',
#   'around',
#   'red',
#   'vehicle',
#   'appeared',
#   'circling',
#   'around',
#   'vicinity',
#   'street',
#   'course',
#   '2½',
#   'hours',
#   'pulling',
#   'vehicle',
#   'officers',
#   'noticed',
#   'one',
#   'rolled',
#   'ski',
#   'mask',
#   'pocket',
#   'vodka',
#   'nips',
#   'glove',
#   'box',
#   'vehicle',
#   'police',
#   'said',
#   'police',
#   'reported',
#   'continued',
#   'nervously',
#   'glance',
#   'backpack',
#   'backseat',
#   'car',
#   'officers',
#   'patted',
#   'backpack',
#   'felt',
#   'believed',
#   'firearm',
#   'inside',
#   'police',
#   'said',
#   'recovered',
#   'loaded',
#   'black',
#   'semi',
#   'automatic',
#   'firearm',
#   'backpack',
#   'well',
#   'two',
#   'clear',
#   'plastic',
#   'bags',
#   'believed',
#   'marijuana',
#   'along',
#   'digital',
#   'scale',
#   'box',
#   'clear',
#   'plastic',
#   'sandwich',
#   ...],
#  ['crackdown',
#   'gang',
#   'activity',
#   'mildred',
#   'hailey',
#   'apartments',
#   'complex',
#   'jamaica',
#   'plain',
#   'yielded',
#   'federal',
#   'indictments',
#   'nine',
#   'young',
#   'men',
#   'drug',
#   'gun',
#   'charges',
#   'officials',
#   'said',
#   'monday',
#   'eight',
#   'suspects',
#   'members',
#   'violent',
#   'heath',
#   'street',
#   'gang',
#   'according',
#   'legal',
#   'filings',
#   'sweep',
#   'tip',
#   'iceberg',
#   'said',
#   'boston',
#   'police',
#   'commissioner',
#   'william',
#   'evans',
#   'going',
#   'continue',
#   'go',
#   'heath',
#   'street',
#   'members',
#   'evans',
#   'said',
#   'next',
#   'developments',
#   'mission',
#   'hill',
#   'annunciation',
#   'road',
#   'also',
#   'seen',
#   'uptick',
#   'violence',
#   'going',
#   'take',
#   'one',
#   'gang',
#   'time',
#   'state',
#   'representative',
#   'jeffrey',
#   'sanchez',
#   'whose',
#   'district',
#   'includes',
#   'hailey',
#   'complex',
#   'lauded',
#   'investigators',
#   'work',
#   'said',
#   'community',
#   'stakeholders',
#   'working',
#   'local',
#   'youth',
#   'effort',
#   'stop',
#   'wave',
#   'violence',
#   'today',
#   'big',
#   'piece',
#   'said',
#   'affidavit',
#   'filed',
#   'case',
#   'atf',
#   'special',
#   'agent',
#   'keltar',
#   'mui',
#   'said',
#   'hailey',
#   'complex',
#   'formerly',
#   'bromley',
#   'heath',
#   'site',
#   'frequent',
#   'violence',
#   'january',
#   'dec',
#   'ten',
#   'last',
#   'year',
#   'including',
#   'one',
#   'murder',
#   'eight',
#   'nonfatal',
#   'shootings',
#   'twenty',
#   'five',
#   'robberies',
#   'twenty',
#   'drug',
#   'arrests',
#   'made',
#   'homicide',
#   'victim',
#   'sixteen',
#   'year',
#   'old',
#   'gerrod',
#   'brown',
#   'gunned',
#   'halloween',
#   'night',
#   'none',
#   'men',
#   'named',
#   'federal',
#   'indictment',
#   'charged',
#   'brown',
#   'murder',
#   'evans',
#   'said',
#   'investigation',
#   'slaying',
#   'remains',
#   'active',
#   'among',
#   'charged',
#   'heath',
#   'street',
#   'gang',
#   'members',
#   'dominique',
#   'heff',
#   'finch',
#   'twenty',
#   'seven',
#   'brother',
#   'james',
#   'finch',
#   'thirty',
#   'two',
#   'kendrick',
#   'roc',
#   'tate',
#   'twenty',
#   'five',
#   'cerone',
#   'jp',
#   'davis',
#   'twenty',
#   'five',
#   'joe',
#   'profit',
#   'simmons',
#   'thirty',
#   'brother',
#   'jarrod',
#   'rizz',
#   'simmons',
#   'twenty',
#   'one',
#   'kevin',
#   'works',
#   'smith',
#   'twenty',
#   'seven',
#   'javonte',
#   'big',
#   'dog',
#   'robinson',
#   'twenty',
#   'one',
#   'ninth',
#   'defendant',
#   'franklin',
#   'frankie',
#   'smooth',
#   'safo',
#   'agyare',
#   'twenty',
#   'five',
#   'heath',
#   'street',
#   'member',
#   'charged',
#   'felon',
#   'possession',
#   'firearm',
#   'gun',
#   'sale',
#   'allegedly',
#   'made',
#   'cooperating',
#   'witness',
#   'parking',
#   'lot',
#   'next',
#   'hailey',
#   'apartments',
#   'mui',
#   'wrote',
#   'dominique',
#   'finch',
#   'constant',
#   'presence',
#   'development',
#   'shot',
#   'twice',
#   'separate',
#   'incidents',
#   'charged',
#   'selling',
#   'crack',
#   'cocaine',
#   'within',
#   'zero',
#   'feet',
#   'complex',
#   'according',
#   'police',
#   'court',
#   'records',
#   'tate',
#   'currently',
#   'serving',
#   'state',
#   'prison',
#   'sentenced',
#   'unrelated',
#   'charges',
#   'shot',
#   'two',
#   'thousand',
#   'eleven',
#   'affidavit',
#   'said',
#   'federal',
#   'case',
#   'allegedly',
#   'sold',
#   'crack',
#   'cocaine',
#   'gun',
#   'cooperating',
#   'witness',
#   'april',
#   'robinson',
#   'charged',
#   'selling',
#   'crack',
#   'cocaine',
#   'emerged',
#   'one',
#   'active',
#   'dealers',
#   'investigation',
#   'mui',
#   'wrote',
#   'robinson',
#   'shot',
#   'chest',
#   'two',
#   'thousand',
#   'fourteen',
#   'told',
#   'cooperating',
#   'witness',
#   'current',
#   'case',
#   'sending',
#   'ten',
#   'guns',
#   'including',
#   'chopper',
#   'slang',
#   'assault',
#   'rifle',
#   'projects',
#   'retaliate',
#   'anyone',
#   'responsible',
#   'murdering',
#   'one',
#   'friends',
#   'affidavit',
#   'said',
#   'unclear',
#   'friend',
#   'gangs',
#   'organized',
#   'long',
#   'term',
#   'threat',
#   'neighborhoods',
#   'said',
#   'us',
#   'attorney',
#   'andrew',
#   'lelling',
#   'statement',
#   'us',
#   'right',
#   'live',
#   'safe',
#   'communities',
#   'without',
#   'fear',
#   'getting',
#   'hurt',
#   'subjected',
#   'drug',
#   'dealing',
#   'street',
#   'corners',
#   'children',
#   'recruited',
#   'life',
#   'crime',
#   'crackdown',
#   'gang',
#   'activity',
#   'mildred',
#   'hailey',
#   'apartments',
#   'complex',
#   'jamaica',
#   'plain',
#   'yielded',
#   'federal',
#   'indictments',
#   'nine',
#   'young',
#   'men',
#   'drug',
#   'gun',
#   'charges',
#   'officials',
#   'said',
#   'monday',
#   'eight',
#   'suspects',
#   'members',
#   'violent',
#   'heath',
#   'street',
#   'gang',
#   'according',
#   'legal',
#   'filings',
#   'sweep',
#   'tip',
#   'iceberg',
#   'said',
#   'boston',
#   'police',
#   'commissioner',
#   'william',
#   'evans',
#   'going',
#   'continue',
#   'go',
#   'heath',
#   'street',
#   'members',
#   'evans',
#   'said',
#   'next',
#   'developments',
#   'mission',
#   'hill',
#   'annunciation',
#   'road',
#   'also',
#   'seen',
#   'uptick',
#   'violence',
#   'going',
#   'take',
#   'one',
#   'gang',
#   'time',
#   'state',
#   'representative',
#   'jeffrey',
#   'sanchez',
#   'whose',
#   'district',
#   'includes',
#   'hailey',
#   'complex',
#   'lauded',
#   'investigators',
#   'work',
#   'said',
#   'community',
#   'stakeholders',
#   'working',
#   'local',
#   'youth',
#   'effort',
#   'stop',
#   'wave',
#   'violence',
#   'today',
#   'big',
#   'piece',
#   'said',
#   'affidavit',
#   'filed',
#   'case',
#   'atf',
#   'special',
#   'agent',
#   'keltar',
#   'mui',
#   'said',
#   'hailey',
#   'complex',
#   'formerly',
#   'bromley',
#   'heath',
#   'site',
#   'frequent',
#   'violence',
#   'january',
#   'dec',
#   'ten',
#   'last',
#   'year',
#   'including',
#   'one',
#   'murder',
#   'eight',
#   'nonfatal',
#   'shootings',
#   'twenty',
#   'five',
#   'robberies',
#   'twenty',
#   'drug',
#   'arrests',
#   'made',
#   'homicide',
#   'victim',
#   'sixteen',
#   'year',
#   'old',
#   'gerrod',
#   'brown',
#   'gunned',
#   'halloween',
#   'night',
#   'none',
#   'men',
#   'named',
#   'federal',
#   'indictment',
#   'charged',
#   'brown',
#   'murder',
#   'evans',
#   'said',
#   'investigation',
#   'slaying',
#   'remains',
#   'active',
#   'among',
#   'charged',
#   'heath',
#   'street',
#   'gang',
#   'members',
#   'dominique',
#   'heff',
#   'finch',
#   'twenty',
#   'seven',
#   'brother',
#   'james',
#   'finch',
#   'thirty',
#   'two',
#   'kendrick',
#   'roc',
#   'tate',
#   'twenty',
#   'five',
#   'cerone',
#   'jp',
#   'davis',
#   'twenty',
#   'five',
#   'joe',
#   'profit',
#   'simmons',
#   'thirty',
#   'brother',
#   'jarrod',
#   'rizz',
#   'simmons',
#   'twenty',
#   'one',
#   'kevin',
#   'works',
#   'smith',
#   'twenty',
#   'seven',
#   'javonte',
#   'big',
#   'dog',
#   'robinson',
#   'twenty',
#   'one',
#   'ninth',
#   'defendant',
#   'franklin',
#   'frankie',
#   'smooth',
#   'safo',
#   'agyare',
#   'twenty',
#   'five',
#   'heath',
#   'street',
#   'member',
#   'charged',
#   'felon',
#   'possession',
#   'firearm',
#   'gun',
#   'sale',
#   'allegedly',
#   'made',
#   'cooperating',
#   'witness',
#   'parking',
#   'lot',
#   'next',
#   'hailey',
#   'apartments',
#   'mui',
#   'wrote',
#   'dominique',
#   'finch',
#   'constant',
#   'presence',
#   'development',
#   'shot',
#   'twice',
#   'separate',
#   'incidents',
#   'charged',
#   'selling',
#   'crack',
#   'cocaine',
#   'within',
#   'zero',
#   'feet',
#   'complex',
#   'according',
#   'police',
#   'court',
#   'records',
#   'tate',
#   'currently',
#   'serving',
#   'state',
#   'prison',
#   'sentenced',
#   'unrelated',
#   'charges',
#   'shot',
#   'two',
#   'thousand',
#   'eleven',
#   'affidavit',
#   'said',
#   'federal',
#   'case',
#   'allegedly',
#   'sold',
#   'crack',
#   'cocaine',
#   'gun',
#   'cooperating',
#   'witness',
#   'april',
#   'robinson',
#   'charged',
#   'selling',
#   'crack',
#   'cocaine',
#   'emerged',
#   'one',
#   'active',
#   'dealers',
#   'investigation',
#   'mui',
#   'wrote',
#   'robinson',
#   'shot',
#   'chest',
#   'two',
#   'thousand',
#   'fourteen',
#   'told',
#   'cooperating',
#   'witness',
#   'current',
#   'case',
#   'sending',
#   'ten',
#   'guns',
#   'including',
#   'chopper',
#   'slang',
#   'assault',
#   'rifle',
#   'projects',
#   'retaliate',
#   'anyone',
#   'responsible',
#   'murdering',
#   'one',
#   'friends',
#   'affidavit',
#   'said',
#   'unclear',
#   'friend',
#   'gangs',
#   'organized',
#   'long',
#   'term',
#   'threat',
#   'neighborhoods',
#   'said',
#   'us',
#   'attorney',
#   'andrew',
#   'lelling',
#   'statement',
#   'us',
#   'right',
#   'live',
#   'safe',
#   'communities',
#   'without',
#   'fear',
#   'getting',
#   'hurt',
#   'subjected',
#   'drug',
#   'dealing',
#   'street',
#   'corners',
#   'children',
#   'recruited',
#   'life',
#   'crime',
#   'given',
#   'sleadership',
#   'position',
#   'diversifying',
#   'ranks',
#   'boston',
#   'corporate',
#   'elite',
#   'come',
#   'surprise',
#   'new',
#   'lead',
#   'director',
#   'black',
#   'woman',
#   'takes',
#   'reins',
#   'month',
#   'boston',
#   'based',
#   'bank',
#   'first',
#   'woman',
#   'lead',
#   'director',
#   'position',
#   'institution',
#   'two',
#   'hundred',
#   'year',
#   'history',
#   'jackson',
#   'role',
#   'include',
#   'running',
#   'portions',
#   'board',
#   'meetings',
#   'ceo',
#   'chairman',
#   'present',
#   'acting',
#   'liaison',
#   'rivers',
#   'board',
#   'members',
#   'meanwhile',
#   'continue',
#   'busy',
#   'day',
#   'job',
#   'president',
#   'jackson',
#   'succeeds',
#   'lead',
#   'director',
#   'since',
#   'two',
#   'thousand',
#   'nine',
#   'knox',
#   'retire',
#   'board',
#   'end',
#   'two',
#   'thousand',
#   'eighteen',
#   'jackson',
#   'knox',
#   'search',
#   'committee',
#   'hired',
#   'rivers',
#   'two',
#   'thousand',
#   'six',
#   'brought',
#   'back',
#   'boston',
#   'area',
#   'grew',
#   'nebraska',
#   'jackson',
#   'rivers',
#   'says',
#   'tremendous',
#   'adviser',
#   'years',
#   'lot',
#   'us',
#   'spending',
#   'time',
#   'deliberating',
#   'trees',
#   'often',
#   'one',
#   'gets',
#   'us',
#   'pick',
#   'heads',
#   'consider',
#   'forest',
#   'rivers',
#   'says',
#   'eastern',
#   'rivers',
#   'direction',
#   'recently',
#   'decided',
#   'spend',
#   'ten',
#   'million',
#   'foundation',
#   'three',
#   'years',
#   'improve',
#   'diversity',
#   'within',
#   'city',
#   'business',
#   'community',
#   'eastern',
#   'divvying',
#   'money',
#   'three',
#   'ways',
#   'supporting',
#   'program',
#   'help',
#   'connect',
#   'minority',
#   'owned',
#   'businesses',
#   'big',
#   'employers',
#   'pairing',
#   'minority',
#   'entrepreneurs',
#   'strategic',
#   'advisers',
#   'establishing',
#   'new',
#   'fund',
#   'make',
#   'equity',
#   'investments',
#   'loans',
#   'types',
#   'firms',
#   'jackson',
#   'recruited',
#   'board',
#   'nearly',
#   'two',
#   'decades',
#   'ago',
#   'ceo',
#   'eastern',
#   'moving',
#   'beyond',
#   'north',
#   'shore',
#   'base',
#   'expanding',
#   'boston',
#   'presence',
#   'ceos',
#   'recognized',
#   'importance',
#   'diverse',
#   'set',
#   'voices',
#   'board',
#   'joy',
#   'bank',
#   'never',
#   'loses',
#   'sight',
#   'fiduciary',
#   'obligations',
#   'jackson',
#   'says',
#   'time',
#   'never',
#   'compromises',
#   'core',
#   'values',
#   'justice',
#   'opportunity',
#   'jon',
#   'chesto',
#   'says',
#   'firm',
#   'finally',
#   'reaching',
#   'sweet',
#   'spot',
#   'large',
#   'enough',
#   'compete',
#   'big',
#   'law',
#   'firms',
#   'litigation',
#   'departments',
#   'small',
#   'enough',
#   'represent',
#   'clients',
#   'relatively',
#   'affordable',
#   'price',
#   'one',
#   'big',
#   'reason',
#   'four',
#   'experienced',
#   'trial',
#   'attorneys',
#   'formerly',
#   'boston',
#   'boutique',
#   'firm',
#   'collora',
#   'joined',
#   'todd',
#   'weld',
#   'partners',
#   'following',
#   'recent',
#   'merger',
#   'giant',
#   'global',
#   'firm',
#   'weld',
#   'founding',
#   'partner',
#   'todd',
#   'weld',
#   'says',
#   'four',
#   'lawyers',
#   'approached',
#   'firm',
#   'group',
#   'mid',
#   'two',
#   'thousand',
#   'seventeen',
#   'collora',
#   'quietly',
#   'preparing',
#   'merger',
#   'deal',
#   'publicly',
#   'announced',
#   'looked',
#   'fit',
#   'talked',
#   'xa0',
#   'xa0',
#   'saw',
#   'unique',
#   'opportunity',
#   'weld',
#   'says',
#   'nearly',
#   'forty',
#   'five',
#   'lawyers',
#   'work',
#   'todd',
#   'weld',
#   'focused',
#   'various',
#   'aspects',
#   'litigation',
#   'group',
#   'includes',
#   'sixteen',
#   'partners',
#   'plus',
#   'four',
#   'newcomers',
#   'collora',
#   'weld',
#   'says',
#   'firm',
#   'size',
#   'bigger',
#   'litigation',
#   'departments',
#   'many',
#   'big',
#   'firms',
#   'town',
#   'afford',
#   'less',
#   'expensive',
#   'without',
#   'overhead',
#   'full',
#   'size',
#   'firm',
#   'focusing',
# ...
#   'universe',
#   'said',
#   'moschella',
#   'second',
#   'dog',
#   'named',
#   'rocko',
#   'go',
#   'outside',
#   'people',
#   'said',
#   'stop',
#   'watching',
#   'repeat',
#   'wild',
#   'racetrack',
#   'project',
#   'born',
#   'desperation',
#   'get',
#   'two',
#   'greyhounds',
#   'exercise',
#   'refused',
#   'venture',
#   'bitter',
#   'cold',
#   'followed',
#   'storm',
#   'great',
#   'dogs',
#   'sensitive',
#   'cold',
#   'need',
#   'lot',
#   'clothes',
#   'stay',
#   'warm',
#   'said',
#   'make',
#   'yard',
#   'shoveled',
#   'driveway',
#   'hours',
#   'shoveled',
#   'sidewalk',
#   'thought',
#   'would',
#   'shovel',
#   'little',
#   'path',
#   'dogs',
#   'relieve',
#   'cold',
#   'kind',
#   'got',
#   'gave',
#   'place',
#   'walk',
#   'walking',
#   'soon',
#   'turned',
#   'running',
#   'however',
#   'vicki',
#   'lost',
#   'mind',
#   'racetrack',
#   'said',
#   'response',
#   'tweet',
#   'thousands',
#   'greyhound',
#   'owners',
#   'started',
#   'sharing',
#   'photos',
#   'cooped',
#   'dogs',
#   'contending',
#   'winter',
#   'weather',
#   'said',
#   'moschella',
#   'said',
#   'typically',
#   'uses',
#   'social',
#   'media',
#   'share',
#   'news',
#   'information',
#   'rare',
#   'books',
#   'collections',
#   'library',
#   'tweet',
#   'went',
#   'viral',
#   'reconsidering',
#   'career',
#   'path',
#   'maybe',
#   'even',
#   'open',
#   'dog',
#   'track',
#   'full',
#   'time',
#   'people',
#   'bringing',
#   'dogs',
#   'run',
#   'said',
#   'local',
#   'attraction',
#   'dogs',
#   'running',
#   'wonderland',
#   'greyhound',
#   'park',
#   'days',
#   'racing',
#   'full',
#   'swing',
#   'roslindale',
#   'last',
#   'week',
#   'following',
#   'intense',
#   'biting',
#   'winter',
#   'storm',
#   'rare',
#   'books',
#   'curator',
#   'boston',
#   'public',
#   'library',
#   'posted',
#   'video',
#   'twitter',
#   'friday',
#   'featuring',
#   'homemade',
#   'racetrack',
#   'shoveled',
#   'backyard',
#   'greyhounds',
#   'much',
#   'region',
#   'blanketed',
#   'foot',
#   'snow',
#   'jan',
#   'tweet',
#   'showed',
#   'one',
#   'canines',
#   'vicki',
#   'wearing',
#   'vest',
#   'darted',
#   'formula',
#   'like',
#   'course',
#   'behind',
#   'moschella',
#   'home',
#   'thirteen',
#   'seconds',
#   'full',
#   'speed',
#   'moschella',
#   'video',
#   'racked',
#   'million',
#   'views',
#   'sixty',
#   'zero',
#   'shares',
#   'online',
#   'monday',
#   'morning',
#   'taking',
#   'roslindale',
#   'resident',
#   'complete',
#   'surprise',
#   'next',
#   'thing',
#   'know',
#   'people',
#   'inundating',
#   'around',
#   'universe',
#   'said',
#   'moschella',
#   'second',
#   'dog',
#   'named',
#   'rocko',
#   'go',
#   'outside',
#   'people',
#   'said',
#   'stop',
#   'watching',
#   'repeat',
#   'wild',
#   'racetrack',
#   'project',
#   'born',
#   'desperation',
#   'get',
#   'two',
#   'greyhounds',
#   'exercise',
#   'refused',
#   'venture',
#   'bitter',
#   'cold',
#   'followed',
#   'storm',
#   'great',
#   'dogs',
#   'sensitive',
#   'cold',
#   'need',
#   'lot',
#   'clothes',
#   'stay',
#   'warm',
#   'said',
#   'make',
#   'yard',
#   'shoveled',
#   'driveway',
#   'hours',
#   'shoveled',
#   'sidewalk',
#   'thought',
#   'would',
#   'shovel',
#   'little',
#   'path',
#   'dogs',
#   'relieve',
#   'cold',
#   'kind',
#   'got',
#   'gave',
#   'place',
#   'walk',
#   'walking',
#   'soon',
#   'turned',
#   'running',
#   'however',
#   'vicki',
#   'lost',
#   'mind',
#   'racetrack',
#   'said',
#   'response',
#   'tweet',
#   'thousands',
#   'greyhound',
#   'owners',
#   'started',
#   'sharing',
#   'photos',
#   'cooped',
#   'dogs',
#   'contending',
#   'winter',
#   'weather',
#   'said',
#   'moschella',
#   'said',
#   'typically',
#   'uses',
#   'social',
#   'media',
#   'share',
#   'news',
#   'information',
#   'rare',
#   'books',
#   'collections',
#   'library',
#   'tweet',
#   'went',
#   'viral',
#   'reconsidering',
#   'career',
#   'path',
#   'maybe',
#   'even',
#   'open',
#   'dog',
#   'track',
#   'full',
#   'time',
#   'people',
#   'bringing',
#   'dogs',
#   'run',
#   'said',
#   'local',
#   'attraction',
#   'dogs',
#   'running',
#   'wonderland',
#   'greyhound',
#   'park',
#   'days',
#   'racing',
#   'full',
#   'swing',
#   'roslindale',
#   'last',
#   'week',
#   'following',
#   'intense',
#   'biting',
#   'winter',
#   ...],
#  ['five',
#   'alarm',
#   'fire',
#   'heavily',
#   'damaged',
#   'three',
#   'decker',
#   'allston',
#   'street',
#   'dorchester',
#   'late',
#   'saturday',
#   'night',
#   'boston',
#   'fire',
#   'department',
#   'said',
#   'one',
#   'hundred',
#   'firefighters',
#   'battled',
#   'extreme',
#   'cold',
#   'icy',
#   'conditions',
#   'densely',
#   'populated',
#   'neighborhood',
#   'fire',
#   'roared',
#   'wood',
#   'framed',
#   'house',
#   'allston',
#   'st',
#   'located',
#   'near',
#   'st',
#   'mark',
#   'church',
#   'shawmut',
#   'mbta',
#   'station',
#   'cause',
#   'fire',
#   'remained',
#   'investigation',
#   'fire',
#   'commissioner',
#   'joseph',
#   'finn',
#   'said',
#   'fire',
#   'scene',
#   'early',
#   'sunday',
#   'morning',
#   'crews',
#   'expected',
#   'remain',
#   'scene',
#   'overnight',
#   'fire',
#   'officials',
#   'said',
#   'certainly',
#   'battling',
#   'weather',
#   'conditions',
#   'ice',
#   'cold',
#   'difficult',
#   'finn',
#   'said',
#   'shortly',
#   'midnight',
#   'firefighters',
#   'continued',
#   'trying',
#   'extinguish',
#   'blaze',
#   'top',
#   'floor',
#   'building',
#   'fourteen',
#   'residents',
#   'property',
#   'accounted',
#   'young',
#   'child',
#   'elderly',
#   'woman',
#   'initially',
#   'considered',
#   'missing',
#   'found',
#   'safe',
#   'finn',
#   'said',
#   'injuries',
#   'reported',
#   'midnight',
#   'saturday',
#   'finn',
#   'said',
#   'seemed',
#   'extended',
#   'family',
#   'lived',
#   'home',
#   'dozens',
#   'firefighters',
#   'attacked',
#   'blaze',
#   'multiple',
#   'angles',
#   'ladder',
#   'trucks',
#   'extended',
#   'top',
#   'structure',
#   'heavy',
#   'smoke',
#   'poured',
#   'windows',
#   'filled',
#   'surrounding',
#   'streets',
#   'firefighters',
#   'could',
#   'seen',
#   'porches',
#   'first',
#   'second',
#   'stories',
#   'buildings',
#   'either',
#   'side',
#   'allston',
#   'st',
#   'even',
#   'finn',
#   'said',
#   'fire',
#   'extended',
#   'side',
#   'white',
#   'triple',
#   'decker',
#   'corner',
#   'allston',
#   'centre',
#   'streets',
#   'granville',
#   'pusey',
#   'whose',
#   'mother',
#   'lives',
#   'white',
#   'house',
#   'drove',
#   'home',
#   'geneva',
#   'avenue',
#   'around',
#   'eleven',
#   'brother',
#   'alerted',
#   'fire',
#   'spread',
#   'caught',
#   'mother',
#   'house',
#   'side',
#   'looked',
#   'like',
#   'said',
#   'standing',
#   'behind',
#   'police',
#   'caution',
#   'tape',
#   'centre',
#   'street',
#   'several',
#   'blocks',
#   'fire',
#   'thick',
#   'yellow',
#   'hose',
#   'extended',
#   'way',
#   'street',
#   'pusey',
#   'mother',
#   'got',
#   'home',
#   'neighbor',
#   'house',
#   'said',
#   'hoping',
#   'find',
#   'diane',
#   'shepherd',
#   'said',
#   'smoke',
#   'forced',
#   'brick',
#   'apartment',
#   'building',
#   'centre',
#   'street',
#   'around',
#   'corner',
#   'breathe',
#   'smoke',
#   'said',
#   'smoke',
#   'intense',
#   'alarms',
#   'going',
#   'building',
#   'think',
#   'shut',
#   'came',
#   'back',
#   'going',
#   'anywhere',
#   'said',
#   'pointing',
#   'smoke',
#   'billowing',
#   'air',
#   'barry',
#   'quinn',
#   'said',
#   'driving',
#   'car',
#   'shortly',
#   'eleven',
#   'turned',
#   'onto',
#   'nearby',
#   'dorchester',
#   'avenue',
#   'saw',
#   'multiple',
#   'police',
#   'fire',
#   'vehicles',
#   'could',
#   'smell',
#   'smoke',
#   'car',
#   'came',
#   'saw',
#   'smoke',
#   'coming',
#   'said',
#   'temperature',
#   'degree',
#   'midnight',
#   'water',
#   'instantly',
#   'froze',
#   'exterior',
#   'structure',
#   'power',
#   'lines',
#   'overhead',
#   'firefighting',
#   'foam',
#   'filled',
#   'space',
#   'fire',
#   'trucks',
#   'narrow',
#   'hilly',
#   'allston',
#   'street',
#   'blending',
#   'snow',
#   'ground',
#   'heavy',
#   'fire',
#   'already',
#   'showing',
#   'fire',
#   'crews',
#   'arrived',
#   'scene',
#   'ten',
#   'five',
#   'boston',
#   'fire',
#   'department',
#   'building',
#   'third',
#   'floor',
#   'porch',
#   'fully',
#   'involved',
#   'early',
#   'stage',
#   'fire',
#   'heavy',
#   'smoke',
#   'showing',
#   'department',
#   'wrote',
#   'twitter',
#   'mayor',
#   'martin',
#   'walsh',
#   'briefed',
#   'scene',
#   'finn',
#   'eleven',
#   'thirty',
#   'multiple',
#   'streets',
#   'closed',
#   'near',
#   'fire',
#   'scene',
#   'steve',
#   'macdonald',
#   'fire',
#   'department',
#   'spokesman',
#   'said',
#   'intensity',
#   'fire',
#   'caused',
#   'five',
#   'alarms',
#   'brought',
#   'one',
#   'hundred',
#   'firefighters',
#   'scene',
#   'finn',
#   'said',
#   'extra',
#   'crews',
#   'duty',
#   'saturday',
#   'night',
#   'extreme',
#   'cold',
#   'commended',
#   'work',
#   'blessed',
#   'city',
#   'appropriate',
#   'equipment',
#   'manpower',
#   'deal',
#   'said',
#   'imagine',
#   'much',
#   'difficult',
#   'work',
#   'weather',
#   'fatigue',
#   'firefighters',
#   'conditions',
#   'make',
#   'difficult',
#   'sufficient',
#   'manpower',
#   'tonight',
#   'make',
#   'happen',
#   'five',
#   'alarm',
#   'fire',
#   'heavily',
#   'damaged',
#   'three',
#   'decker',
#   'allston',
#   'street',
#   'dorchester',
#   'late',
#   'saturday',
#   'night',
#   'boston',
#   'fire',
#   'department',
#   'said',
#   'one',
#   'hundred',
#   'firefighters',
#   'battled',
#   'extreme',
#   'cold',
#   'icy',
#   'conditions',
#   'densely',
#   'populated',
#   'neighborhood',
#   'fire',
#   'roared',
#   'wood',
#   'framed',
#   'house',
#   'allston',
#   'st',
#   'located',
#   'near',
#   'st',
#   'mark',
#   'church',
#   'shawmut',
#   'mbta',
#   'station',
#   'cause',
#   'fire',
#   'remained',
#   'investigation',
#   'fire',
#   'commissioner',
#   'joseph',
#   'finn',
#   'said',
#   'fire',
#   'scene',
#   'early',
#   'sunday',
#   'morning',
#   'crews',
#   'expected',
#   'remain',
#   'scene',
#   'overnight',
#   'fire',
#   'officials',
#   'said',
#   'certainly',
#   'battling',
#   'weather',
#   'conditions',
#   'ice',
#   'cold',
#   'difficult',
#   'finn',
#   'said',
#   'shortly',
#   'midnight',
#   'firefighters',
#   'continued',
#   'trying',
#   'extinguish',
#   'blaze',
#   'top',
#   'floor',
#   'building',
#   'fourteen',
#   'residents',
#   'property',
#   'accounted',
#   'young',
#   'child',
#   'elderly',
#   'woman',
#   'initially',
#   'considered',
#   'missing',
#   'found',
#   'safe',
#   'finn',
#   'said',
#   'injuries',
#   'reported',
#   'midnight',
#   'saturday',
#   'finn',
#   'said',
#   'seemed',
#   'extended',
#   'family',
#   'lived',
#   'home',
#   'dozens',
#   'firefighters',
#   'attacked',
#   'blaze',
#   'multiple',
#   'angles',
#   'ladder',
#   'trucks',
#   'extended',
#   'top',
#   'structure',
#   'heavy',
#   'smoke',
#   'poured',
#   'windows',
#   'filled',
#   'surrounding',
#   'streets',
#   'firefighters',
#   'could',
#   'seen',
#   'porches',
#   'first',
#   'second',
#   'stories',
#   'buildings',
#   'either',
#   'side',
#   'allston',
#   'st',
#   'even',
#   'finn',
#   'said',
#   'fire',
#   'extended',
#   'side',
#   'white',
#   'triple',
#   'decker',
#   'corner',
#   'allston',
#   'centre',
#   'streets',
#   'granville',
#   'pusey',
#   'whose',
#   'mother',
#   'lives',
#   'white',
#   'house',
#   'drove',
#   'home',
#   'geneva',
#   'avenue',
#   'around',
#   'eleven',
#   'brother',
#   'alerted',
#   'fire',
#   'spread',
#   'caught',
#   'mother',
#   'house',
#   'side',
#   'looked',
#   'like',
#   'said',
#   'standing',
#   'behind',
#   'police',
#   'caution',
#   'tape',
#   'centre',
#   'street',
#   'several',
#   'blocks',
#   'fire',
#   'thick',
#   'yellow',
#   'hose',
#   'extended',
#   'way',
#   'street',
#   'pusey',
#   'mother',
#   'got',
#   'home',
#   'neighbor',
#   'house',
#   'said',
#   'hoping',
#   'find',
#   'diane',
#   'shepherd',
#   'said',
#   'smoke',
#   'forced',
#   'brick',
#   'apartment',
#   'building',
#   'centre',
#   'street',
#   'around',
#   'corner',
#   'breathe',
#   'smoke',
#   'said',
#   'smoke',
#   'intense',
#   'alarms',
#   'going',
#   'building',
#   'think',
#   'shut',
#   'came',
#   'back',
#   'going',
#   'anywhere',
#   'said',
#   'pointing',
#   'smoke',
#   'billowing',
#   'air',
#   'barry',
#   'quinn',
#   'said',
#   'driving',
#   'car',
#   'shortly',
#   'eleven',
#   'turned',
#   'onto',
#   'nearby',
#   'dorchester',
#   'avenue',
#   'saw',
#   'multiple',
#   'police',
#   'fire',
#   'vehicles',
#   'could',
#   'smell',
#   'smoke',
#   'car',
#   'came',
#   'saw',
#   'smoke',
#   'coming',
#   'said',
#   'temperature',
#   'degree',
#   'midnight',
#   'water',
#   'instantly',
#   'froze',
#   'exterior',
#   'structure',
#   'power',
#   'lines',
#   'overhead',
#   'firefighting',
#   'foam',
#   'filled',
#   'space',
#   'fire',
#   'trucks',
#   'narrow',
#   'hilly',
#   'allston',
#   'street',
#   'blending',
#   'snow',
#   'ground',
#   'heavy',
#   'fire',
#   'already',
#   'showing',
#   'fire',
#   'crews',
#   'arrived',
#   'scene',
#   'ten',
#   'five',
#   'boston',
#   'fire',
#   'department',
#   'building',
#   'third',
#   'floor',
#   'porch',
#   'fully',
#   'involved',
#   'early',
#   'stage',
#   'fire',
#   'heavy',
#   'smoke',
#   'showing',
#   'department',
#   'wrote',
#   'twitter',
#   'mayor',
#   'martin',
#   'walsh',
#   'briefed',
#   'scene',
#   'finn',
#   'eleven',
#   'thirty',
#   'multiple',
#   'streets',
#   'closed',
#   'near',
#   'fire',
#   'scene',
#   'steve',
#   'macdonald',
#   'fire',
#   'department',
#   'spokesman',
#   'said',
#   'intensity',
#   'fire',
#   'caused',
#   'five',
#   'alarms',
#   'brought',
#   'one',
#   'hundred',
#   'firefighters',
#   'scene',
#   'finn',
#   'said',
#   'extra',
#   'crews',
#   'duty',
#   'saturday',
#   'night',
#   'extreme',
#   'cold',
#   'commended',
#   'work',
#   'blessed',
#   'city',
#   'appropriate',
#   'equipment',
#   'manpower',
#   'deal',
#   'said',
#   'imagine',
#   'much',
#   'difficult',
#   'work',
#   'weather',
#   'fatigue',
#   'firefighters',
#   'conditions',
#   'make',
#   'difficult',
#   'sufficient',
#   'manpower',
#   'tonight',
#   'make',
#   'happen',
#   'dorchester',
#   'residents',
#   'watched',
#   'inferno',
#   'consume',
#   'neighboring',
#   'three',
#   'decker',
#   'frigid',
#   'weather',
#   'saturday',
#   'night',
#   'sunday',
#   'morning',
#   'praised',
#   'boston',
#   'firefighters',
#   'saving',
#   'home',
#   'blaze',
#   'left',
#   'two',
#   'firefighters',
#   'hospitalized',
#   'displaced',
#   'least',
#   'eighteen',
#   'people',
#   'officials',
#   'working',
#   'determine',
#   'cause',
#   'fire',
#   'gutted',
#   'three',
#   'decker',
#   'allston',
#   'st',
#   'damaged',
#   'neighboring',
#   'one',
#   'allston',
#   'st',
#   'said',
#   'boston',
#   'firefighter',
#   'steve',
#   'macdonald',
#   'department',
#   'spokesman',
#   'along',
#   'flames',
#   'firefighters',
#   'battled',
#   'brutal',
#   'cold',
#   'blaze',
#   'roared',
#   'temperatures',
#   'dipped',
#   'low',
#   'minus',
#   'windchill',
#   'teeth',
#   'chattering',
#   'minus',
#   'twenty',
#   'five',
#   'according',
#   'national',
#   'weather',
#   'service',
#   'sustained',
#   'winds',
#   'reached',
#   'twenty',
#   'one',
#   'miles',
#   'per',
#   'hour',
#   'gusts',
#   'thirty',
#   'three',
#   'miles',
#   'per',
#   'hour',
#   'two',
#   'firefighters',
#   'nremained',
#   'hospitalized',
#   'sunday',
#   'evening',
#   'said',
#   'macdonald',
#   'one',
#   'treated',
#   'hypothermia',
#   'undergoing',
#   'evaluation',
#   'neither',
#   'firefighter',
#   'condition',
#   'life',
#   'threatening',
#   'said',
#   'none',
#   'residents',
#   'injured',
#   'damages',
#   'fire',
#   'total',
#   'least',
#   'million',
#   'said',
#   'building',
#   'destroyed',
#   'open',
#   'elements',
#   'going',
#   'total',
#   'loss',
#   'unfortunate',
#   'folks',
#   'live',
#   'said',
#   'macdonald',
#   'fourteen',
#   'members',
#   'extended',
#   'family',
#   'lived',
#   'allston',
#   'st',
#   'least',
#   'another',
#   'four',
#   'people',
#   'lived',
#   'allston',
#   'st',
#   'macdonald',
#   'said',
#   'rachel',
#   'kemper',
#   'forty',
#   'eight',
#   'eric',
#   'thorsen',
#   'fifty',
#   'whose',
#   'allston',
#   'street',
#   'home',
#   'feet',
#   'flames',
#   'credit',
#   'firefighters',
#   'saving',
#   'house',
#   'preventing',
#   'loss',
#   'life',
#   'fled',
#   'neighbor',
#   'house',
#   'fire',
#   'able',
#   'return',
#   'home',
#   'sunday',
#   'morning',
#   'feel',
#   'incredibly',
#   'grateful',
#   'fire',
#   'department',
#   'night',
#   'long',
#   'working',
#   'said',
#   'kemper',
#   'one',
#   'firefighters',
#   'said',
#   'came',
#   'lucked',
#   'said',
#   'luck',
#   'thanks',
#   'firefighters',
#   'first',
#   'called',
#   'shortly',
#   'ten',
#   'call',
#   'quickly',
#   'grew',
#   'five',
#   'alarms',
#   'said',
#   'one',
#   'hundred',
#   'firefighters',
#   'responded',
#   'worked',
#   'early',
#   'morning',
#   'hours',
#   'douse',
#   'fire',
#   'order',
#   'help',
#   'reach',
#   'flames',
#   'deep',
#   'inside',
#   'three',
#   'decker',
#   'firefighters',
#   'ran',
#   'hoses',
#   'neighboring',
#   'building',
#   'allston',
#   'st',
#   'poured',
#   'water',
#   'windows',
#   'joachim',
#   'martillo',
#   'sixty',
#   'one',
#   'said',
#   'inside',
#   'third',
#   'floor',
#   'apartment',
#   'allston',
#   'st',
#   'two',
#   'daughters',
#   'amal',
#   'julia',
#   'eleven',
#   'man',
#   'raced',
#   'stairs',
#   'yelling',
#   'people',
#   'get',
#   'martillo',
#   'looked',
#   ...]]

# %%
DF = {}

# keep track of how many neighborhoods' documents discuss a given token
for i in range(len(df.columns)):
    tokens = processed_text[i]
    for w in tokens:
        try:
            DF[w].add(i)
        except:
            DF[w] = {i}

for i in DF:
    DF[i] = len(DF[i])

# %%
total_vocab_size = len(DF)
total_vocab_size
# Out:
# 43732

# %%
# get the number of documents in which this word occurs
def doc_freq(word):
    c = 0
    try:
        c = DF[word]
    except:
        pass
    return c

# %%
doc = 0

tf_idf = {}

for i in range(len(df.columns)):
    
    # get all the tokenized text for a given neighborhood
    tokens = processed_text[i]
    
    # count the number of times each token occurs in the text for a given neighborhood
    counter = Counter(tokens)
    
    # get the total number of terms for a document (given neighborhood)
    words_count = len(tokens)
    
    for token in np.unique(tokens):
        
        # compute term frequency
        tf = counter[token] / words_count

        # compute inverse document frequency
        dfr = doc_freq(token)
        idf = np.log((len(df.columns) + 1) / (dfr + 1))
        
        # compute tf-idf score
        tf_idf[doc, token] = tf * idf

    doc += 1

# %%
tf_idf
# Out:
# {(0, '100th'): 1.8075881593071357e-05,
#  (0, '107th'): 2.89291920091111e-05,
#  (0, '10th'): 3.082440348906838e-05,
#  (0, '11th'): 9.865669208588734e-06,
#  (0, '12th'): 3.752630172043756e-05,
#  (0, '13milford'): 4.3393788013666645e-05,
#  (0, '14th'): 2.3874469885124573e-05,
#  (0, '1800s'): 1.2508767240145854e-05,
#  (0, '1870s'): 3.6151763186142714e-05,
#  (0, '1900s'): 1.4090424244878134e-05,
#  (0, '1940s'): 1.4090424244878134e-05,
#  (0, '1950s'): 8.73673607498702e-06,
#  (0, '1960s'): 4.298554855663234e-06,
#  (0, '1980s'): 1.7420607026329992e-05,
#  (0, '1990s'): 2.57913291339794e-05,
#  (0, '19th'): 1.1559151308400641e-05,
#  (0, '1a'): 6.326558557574974e-05,
#  (0, '1wilmington'): 1.446459600455555e-05,
#  (0, '1½'): 1.5916313256749718e-05,
#  (0, '209a'): 2.89291920091111e-05,
#  (0, '20s'): 3.223916141747425e-05,
#  (0, '20th'): 1.0746387139158083e-05,
#  (0, '21st'): 1.541220174453419e-05,
#  (0, '22d'): 1.8075881593071357e-05,
#  (0, '23d'): 2.0718979624628477e-05,
#  (0, '28th'): 2.0718979624628477e-05,
#  (0, '2day'): 2.89291920091111e-05,
#  (0, '2¼'): 8.678757602733329e-05,
#  (0, '2½'): 1.0137012587520513e-05,
#  (0, '30s'): 1.747347214997404e-05,
#  (0, '30th'): 2.8180848489756267e-05,
#  (0, '31st'): 8.678757602733329e-05,
#  (0, '32bj'): 0.00012063262820616168,
#  (0, '32d'): 2.412652564123234e-05,
#  (0, '35th'): 2.412652564123234e-05,
#  (0, '3s'): 2.89291920091111e-05,
#  (0, '400th'): 2.0718979624628477e-05,
#  (0, '40th'): 1.8075881593071357e-05,
#  (0, '50s'): 4.7748939770249146e-05,
#  (0, '50th'): 6.34069091019516e-05,
#  (0, '53d'): 2.89291920091111e-05,
#  (0, '5s'): 2.89291920091111e-05,
#  (0, '60s'): 3.3340940666612857e-05,
#  (0, '70s'): 2.9597007625766204e-05,
#  (0, '7th'): 2.0718979624628477e-05,
#  (0, '80s'): 7.706100872267094e-06,
#  (0, '9mm'): 8.73673607498702e-06,
#  (0, 'aaa'): 6.254383620072927e-05,
#  (0, 'aaron'): 2.3653029370881197e-05,
#  (0, 'abandoned'): 3.0378017044259853e-05,
#  (0, 'abandonment'): 0.00012063262820616168,
#  (0, 'abated'): 2.412652564123234e-05,
#  (0, 'battery'): 7.092615511844335e-05,
#  (0, 'battle'): 6.981909388832937e-05,
#  (0, 'battling'): 7.706100872267094e-06,
#  (0, 'bay'): 3.559232171828144e-05,
#  (0, 'bayside'): 6.215693887388542e-05,
#  (0, 'beach'): 1.8210025065167247e-05,
#  (0, 'beaches'): 1.4090424244878134e-05,
#  (0, 'beacon'): 2.6130910539494984e-05,
#  (0, 'beacons'): 4.1437959249256954e-05,
#  (0, 'beaming'): 1.1113646888870953e-05,
#  (0, 'bean'): 7.045212122439067e-05,
#  (0, 'bear'): 2.02520113628399e-05,
#  (0, 'beard'): 1.4090424244878134e-05,
#  (0, 'bearing'): 2.621020822496106e-05,
#  (0, 'beast'): 3.752630172043756e-05,
#  (0, 'beat'): 6.789051943004177e-06,
#  (0, 'beaten'): 2.9597007625766204e-05,
#  (0, 'beating'): 5.063002840709975e-06,
#  (0, 'beaton'): 3.6151763186142714e-05,
#  (0, 'beatty'): 4.1437959249256954e-05,
#  (0, 'beautiful'): 8.277284120530567e-06,
#  (0, 'beauty'): 2.02520113628399e-05,
#  (0, 'became'): 5.544392420120078e-05,
#  (0, 'beckham'): 4.825305128246468e-05,
#  (0, 'beckoning'): 2.89291920091111e-05,
#  (0, 'beckwith'): 2.89291920091111e-05,
#  (0, 'become'): 5.226095638706247e-05,
#  (0, 'becomes'): 6.115715252490914e-05,
#  (0, 'becoming'): 4.935838657460164e-05,
#  (0, 'bed'): 3.0486062296077482e-05,
#  (0, 'bedden'): 0.0003377713589772527,
#  (0, 'bedding'): 8.678757602733329e-05,
#  (0, 'bedford'): 4.809852698674477e-05,
#  (0, 'bedrock'): 1.5916313256749718e-05,
#  (0, 'bedroom'): 2.3176395537485587e-05,
#  (0, 'bedrooms'): 1.1113646888870953e-05,
#  (0, 'beds'): 5.880211860395511e-06,
#  (0, 'beef'): 5.063002840709975e-06,
#  (0, 'beehive'): 2.0718979624628477e-05,
#  (0, 'beeped'): 2.89291920091111e-05,
#  (0, 'beer'): 3.6208277029355615e-05,
#  (0, 'befitting'): 2.89291920091111e-05,
#  (0, 'began'): 6.573027504352188e-05,
#  (0, 'begged'): 4.445458755548381e-05,
#  ...}

# %%
subs = df.columns

# %%
tf_idf_scores = {'dorchester': [], 'roxbury': [], 'mattapan': [], 'hyde_park': [], 'fenway': [],
       'beacon_hill': [], 'downtown': [], 'south_boston': [], 'east_boston': [], 'back_bay': [],
       'jamaica_plain': [], 'south_end': [], 'charlestown': [], 'brighton': [], 'allston': [],
       'west_end': [], 'roslindale': [], 'north_end': [], 'mission_hill': [], 'harbor_islands': [],
       'longwood_medical_area': [], 'west_roxbury': []}

# %%
for key in tf_idf:
    sub_ind, term = key
    tf_idf_scores[subs[sub_ind]].append((term, tf_idf[key]))

# %%
for col in subs:
    tf_idf_scores[col].sort(reverse=True)
    temp = pd.DataFrame(tf_idf_scores[col], columns=['term', 'weight'])
    temp.to_csv('Yearly_TFIDF_Scores_by_Subneighborhood/2018/TFIDF_' + col + '.csv')
